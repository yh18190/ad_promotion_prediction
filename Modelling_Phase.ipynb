# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,roc_auc_score,roc_curve,scorer,f1_score,precision_score,recall_score,log_loss
from lightgbm import LGBMClassifier
import _pickle as pickle
from yellowbrick.classifier import DiscriminationThreshold
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_score, StratifiedKFold
from hyperopt import hp, tpe
from operator import itemgetter
from hyperopt.fmin import fmin
from hyperopt import  fmin, hp, tpe, Trials, STATUS_OK
import plotly.offline as py #visualization
py.init_notebook_mode(connected=True )#visualization
import plotly.graph_objs as go #visualization
import plotly.tools as tls #visualization
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
from  sklearn.metrics  import *
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#path_to_training_data='data_to_train_model.csv'
path_to_training_data='data_hashed_to_train_model.csv'

# %% [markdown]
# #### Load the dataset

# %%
df=pd.read_csv(path_to_training_data)
df.head()
# Out:
#    like  dtype  dconn  pos     A      B    C   D     E  F  ...  \
# 0     0      1      0    0  1005  22605  320  50  2609  3  ...
# 1     1      1      0    1  1005  17877  320  50  2036  3  ...
# 2     0      1      0    0  1005  23801  320  50  2689  2  ...
# 3     0      1      2    0  1005  21189  320  50  2424  1  ...
# 4     1      1      0    4  1005   6563  320  50   572  2  ...
#
#                sid_int          sdomain_int             scat_int  \
# 0   776321843154138061  3785538029929655034 -1211157273377936692
# 1 -5182766089131026688  8234655002540174078  5972868601436526999
# 2   776321843154138061  3785538029929655034 -1211157273377936692
# 3   776321843154138061  3785538029929655034 -1211157273377936692
# 4   840826271303287362 -3686564893281599961  5972868601436526999
#
#                aid_int          adomain_int             acat_int  \
# 0 -3246573411716166988  2910822173347745509  3886391778729123305
# 1  7805814409961345999  -776665081776717179  -957940335628360031
# 2  6557995578601977878  8887649921010694409 -2244377406479595259
# 3 -3947398155323121515 -4943948595311466563 -2244377406479595259
# 4  7805814409961345999  -776665081776717179  -957940335628360031
#
#                did_int              dip_int           dmodel_int  \
# 0 -5967407165868448623  -805082577019723536 -6890509081567746288
# 1  3470267876062906150 -7484785594044394196 -2352365179735405337
# 2  3470267876062906150  6349936201843094265 -2664901439310722939
# 3  3470267876062906150 -1875314767593624304 -6188338516522726698
# 4  3470267876062906150 -5370680276152537106  3094297742463183685
#
#           week_day_int
# 0  5987037459740618995
# 1 -9031220084145463596
# 2 -9031220084145463596
# 3 -5377926922484226834
# 4  1771293467763357270
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['like', 'dtype', 'dconn', 'pos', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H',
#        'I', 'hour_day', 'day', 'sid_int', 'sdomain_int', 'scat_int', 'aid_int',
#        'adomain_int', 'acat_int', 'did_int', 'dip_int', 'dmodel_int',
#        'week_day_int'],
#       dtype='object')

# %% [markdown]
# #### Predictor variable Distribution

# %%
df.like.value_counts(normalize=True)
# Out:
# 0    0.830548
# 1    0.169452
# Name: like, dtype: float64

# %% [markdown]
# #### Compute train,test matrices with 75-25 split of dataset

# %%
X = df.iloc[:, 1:]
y = df.iloc[:, 0]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=130)

# %%
X_train.columns
# Out:
# Index(['dtype', 'dconn', 'pos', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I',
#        'hour_day', 'day', 'sid_int', 'sdomain_int', 'scat_int', 'aid_int',
#        'adomain_int', 'acat_int', 'did_int', 'dip_int', 'dmodel_int',
#        'week_day_int'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: like, dtype: int64

# %% [markdown]
# #### The distribution of target variable in test and training datasets

# %%
y_train.mean(), y_test.mean(), len(y_train), len(y_test)
# Out:
# (0.16934, 0.169788, 750000, 250000)

# %%
features = ['dtype', 'dconn', 'pos', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H',
       'I', 'hour_day', 'day', 'sid_int', 'sdomain_int', 'scat_int', 'aid_int',
       'adomain_int', 'acat_int', 'did_int', 'dip_int', 'dmodel_int',
       'week_day_int']

# %% [markdown]
# User Defined Funtion for Modelling various algorithms

# %%
#cols=features
#Function attributes
#dataframe     - processed dataframe
#Algorithm     - Algorithm used 
#training_x    - predictor variables dataframe(training)
#testing_x     - predictor variables dataframe(testing)
#training_y    - target variable(training)
#training_y    - target variable(testing)
#cf - ["coefficients","features"](cooefficients for logistic 
                                 

#threshold_plot - if True returns threshold plot for model
    
def to_train(algorithm,training_x,testing_x,
                             training_y,testing_y,cols,cf,threshold_plot) :
    
    #model
    algorithm.fit(training_x,training_y)
    predictions   = algorithm.predict(testing_x)
    probabilities = algorithm.predict_proba(testing_x)[:, 1]
    #coeffs
    if   cf == "coefficients" :
        coefficients  = pd.DataFrame(algorithm.coef_.ravel())
    elif cf == "features" :
        coefficients  = pd.DataFrame(algorithm.feature_importances_)
        
    column_df     = pd.DataFrame(cols)
    coef_sumry    = (pd.merge(coefficients,column_df,left_index= True,
                              right_index= True, how = "left"))
    coef_sumry.columns = ["coefficients","features"]
    coef_sumry    = coef_sumry.sort_values(by = "coefficients",ascending = False)
    
    print (algorithm)
    print ("\n Classification report : \n")
    print(classification_report(testing_y,predictions))
    print('-----------------------')
    print ("Accuracy   Score : ",accuracy_score(testing_y,predictions))
    #print('-----------------------')
    #print("F1 score:",f1_score(testing_y,predictions))
    
    #confusion matrix
    conf_matrix = confusion_matrix(testing_y,predictions)
    #roc_auc_score
    model_roc_auc = roc_auc_score(list(testing_y),probabilities) 
    print('-----------------------')
    print ("Area under curve : ",model_roc_auc,"\n")
    fpr,tpr,thresholds = roc_curve(testing_y,probabilities)
    
    
    print("log_loss :", log_loss(testing_y, probabilities))
    
    return coef_sumry[['features','coefficients']]
#     #plot confusion matrix
#     trace1 = go.Heatmap(z = conf_matrix ,
#                         x = ["Not churn","Churn"],
#                         y = ["Not churn","Churn"],
#                         showscale  = False,colorscale = "Picnic",
#                         name = "matrix")
    
#     #plot roc curve
#     trace2 = go.Scatter(x = fpr,y = tpr,
#                         name = "Roc : " + str(model_roc_auc),
#                         line = dict(color = ('rgb(22, 96, 167)'),width = 2))
#     trace3 = go.Scatter(x = [0,1],y=[0,1],
#                         line = dict(color = ('rgb(205, 12, 24)'),width = 2,
#                         dash = 'dot'))
    
    #plot coeffs
    #trace4 = go.Bar(x = coef_sumry["features"],y = coef_sumry["coefficients"],
    #                name = "coefficients",
    #                marker = dict(color = coef_sumry["coefficients"],
    #                              colorscale = "Picnic",
    #                              line = dict(width = .6,color = "black")))
    
    #df_feature_imp=coef_sumry[['features','coefficients']]
#     #subplots
    #fig = tls.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
    #                         subplot_titles=('Confusion Matrix',
    #                                         'Receiver operating characteristic',
    #                                         'Feature Importances'))
    
#     fig.append_trace(trace1,1,1)
#     fig.append_trace(trace2,1,2)
#     fig.append_trace(trace3,1,2)
    #fig.append_trace(trace4,2,1)
    
#     fig['layout'].update(showlegend=False, title="Model performance" ,
#                          autosize = False,height = 900,width = 800,
#                          plot_bgcolor = 'rgba(240,240,240, 0.95)',
#                          paper_bgcolor = 'rgba(240,240,240, 0.95)',
#                          margin = dict(b = 195))
#     fig["layout"]["xaxis2"].update(dict(title = "false positive rate"))
#     fig["layout"]["yaxis2"].update(dict(title = "true positive rate"))
#     fig["layout"]["xaxis3"].update(dict(showgrid = True,tickfont = dict(size = 10),
#                                         tickangle = 90))
    #py.iplot(fig)
    
#     if threshold_plot == True : 
#         visualizer = DiscriminationThreshold(algorithm)
#         visualizer.fit(training_x,training_y)
#         visualizer.poof()
    #return df_feature_imp

# %% [markdown]
# # Logistic Regression with Default Parameters

# %%
logit  = LogisticRegression()

# %%
df_model_logistic=to_train(logit,X_train,X_test,y_train,y_test,cols,"coefficients",threshold_plot = True)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#  Classification report :
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91    207553
#            1       0.00      0.00      0.00     42447
#
#     accuracy                           0.83    250000
#    macro avg       0.42      0.50      0.45    250000
# weighted avg       0.69      0.83      0.75    250000
#
# -----------------------
# Accuracy   Score :  0.830212
# -----------------------
# Area under curve :  0.5
#
# log_loss : 0.693147180559945

# %% [markdown]
# ### Random Forest Classifier with Default Paramters

# %%
rf_model = RandomForestClassifier(random_state=30, n_jobs=-1,  verbose=1)
rf_model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   54.2s finished
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=30, verbose=1,
#                        warm_start=False)

# %%
rf_predprob = rf_model.predict_proba(X_test)[:, 1]
print('The log_loss is ',log_loss(y_test, rf_predprob))
print('The roc_auc score is ',roc_auc_score(y_test, rf_predprob))
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# The log_loss is  0.5270749695299434
# The roc_auc score is  0.7058214356464511
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
rf_predprob = rf_model.predict_proba(X_test)[:, 1]
print('The log_loss is ',log_loss(y_test, rf_predprob))
print('The roc_auc score is ',roc_auc_score(y_test, rf_predprob))
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# The log_loss is  0.53025880986696
# The roc_auc score is  0.7039076458272813
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished

# %% [markdown]
# ### Light GBM with Default Parameters

# %%
##light gbm classifier is one of the boosting algorithm generally known for faster computation and also good at reducing variance and bias.

lgbm_c= LGBMClassifier()

df_model_lightgbm=to_train(lgbm_c,X_train,X_test,y_train,y_test,features,"features",threshold_plot = True)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
#
#  Classification report :
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91    207553
#            1       0.63      0.05      0.09     42447
#
#     accuracy                           0.83    250000
#    macro avg       0.73      0.52      0.50    250000
# weighted avg       0.80      0.83      0.77    250000
#
# -----------------------
# Accuracy   Score :  0.833596
# -----------------------
# Area under curve :  0.73375123193542
#
# log_loss : 0.40481357916365035

# %% [markdown]
# ##### Feature Importance with Lightgbm

# %%
df_model_lightgbm.sort_values('coefficients',ascending=False)
# Out:
#         features  coefficients
# 14       sid_int           379
# 15   sdomain_int           378
# 17       aid_int           300
# 4              B           233
# 22    dmodel_int           192
# 11             I           164
# 18   adomain_int           155
# 16      scat_int           150
# 19      acat_int           114
# 7              E           108
# 9              G           106
# 10             H           100
# 12      hour_day            84
# 2            pos            82
# 8              F            72
# 20       did_int            61
# 1          dconn            54
# 13           day            52
# 6              D            52
# 0          dtype            48
# 21       dip_int            36
# 5              C            30
# 23  week_day_int            27
# 3              A            23

# %% [markdown]
# - We see that Site Domain & Site Id and Application Id seems to be top 3 most important features in the model which influence performance.
#
# - In case of advertisements ,the ad where and through which application is displayed plays an very important for effective user traffic and CTR

# %% [markdown]
# ### Xgboost Classifier with default Parameters

# %%
from xgboost import XGBClassifier
xgb_default_model = XGBClassifier()
df_model_xgb=to_train(xgb_default_model,X_train,X_test,y_train,y_test,features,"features",threshold_plot = True)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
#
#  Classification report :
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91    207553
#            1       0.61      0.06      0.12     42447
#
#     accuracy                           0.83    250000
#    macro avg       0.72      0.53      0.51    250000
# weighted avg       0.80      0.83      0.77    250000
#
# -----------------------
# Accuracy   Score :  0.834124
# -----------------------
# Area under curve :  0.7399010524831775
#
# log_loss : 0.4013914880836443

# %%
df_model_xgb.sort_values('coefficients',ascending=False)
# Out:
#         features  coefficients
# 6              D      0.419103
# 0          dtype      0.068269
# 11             I      0.055209
# 8              F      0.047228
# 2            pos      0.045020
# 16      scat_int      0.041268
# 18   adomain_int      0.037802
# 19      acat_int      0.037529
# 1          dconn      0.037466
# 14       sid_int      0.035071
# 15   sdomain_int      0.033901
# 17       aid_int      0.019858
# 7              E      0.019013
# 9              G      0.017384
# 5              C      0.015681
# 10             H      0.013620
# 4              B      0.013362
# 3              A      0.009469
# 22    dmodel_int      0.007684
# 13           day      0.006510
# 12      hour_day      0.006365
# 20       did_int      0.005785
# 23  week_day_int      0.003891
# 21       dip_int      0.003511

# %% [markdown]
# #### Light GBM with few Parameters

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify  configurations as a dict
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': { 'binary_logloss'},
    'num_leaves': 31, 
    'learning_rate': 0.08,
    
    'verbose': 0
}

print('Start training ---')

lgbm_model_v2 = lgb.train(params,
                lgb_train,
                num_boost_round=4000,
                valid_sets=lgb_eval,
                early_stopping_rounds=500)
# Out:
# Start training ---
# [1]	valid_0's binary_logloss: 0.450214
# Training until validation scores don't improve for 500 rounds
# [2]	valid_0's binary_logloss: 0.445815
# [3]	valid_0's binary_logloss: 0.442102
# [4]	valid_0's binary_logloss: 0.439022
# [5]	valid_0's binary_logloss: 0.43629
# [6]	valid_0's binary_logloss: 0.433821
# [7]	valid_0's binary_logloss: 0.431728
# [8]	valid_0's binary_logloss: 0.429884
# [9]	valid_0's binary_logloss: 0.428235
# [10]	valid_0's binary_logloss: 0.426862
# [11]	valid_0's binary_logloss: 0.4256
# [12]	valid_0's binary_logloss: 0.424374
# [13]	valid_0's binary_logloss: 0.423273
# [14]	valid_0's binary_logloss: 0.422289
# [15]	valid_0's binary_logloss: 0.42131
# [16]	valid_0's binary_logloss: 0.420514
# [17]	valid_0's binary_logloss: 0.419783
# [18]	valid_0's binary_logloss: 0.419004
# [19]	valid_0's binary_logloss: 0.418336
# [20]	valid_0's binary_logloss: 0.417735
# [21]	valid_0's binary_logloss: 0.417227
# [22]	valid_0's binary_logloss: 0.416667
# [23]	valid_0's binary_logloss: 0.416259
# [24]	valid_0's binary_logloss: 0.415882
# [25]	valid_0's binary_logloss: 0.415517
# [26]	valid_0's binary_logloss: 0.415169
# [27]	valid_0's binary_logloss: 0.414763
# [28]	valid_0's binary_logloss: 0.414455
# [29]	valid_0's binary_logloss: 0.414063
# [30]	valid_0's binary_logloss: 0.413727
# [31]	valid_0's binary_logloss: 0.413459
# [32]	valid_0's binary_logloss: 0.413155
# [33]	valid_0's binary_logloss: 0.412876
# [34]	valid_0's binary_logloss: 0.412636
# [35]	valid_0's binary_logloss: 0.412441
# [36]	valid_0's binary_logloss: 0.412233
# [37]	valid_0's binary_logloss: 0.412007
# [38]	valid_0's binary_logloss: 0.411756
# [39]	valid_0's binary_logloss: 0.411522
# [40]	valid_0's binary_logloss: 0.411323
# [41]	valid_0's binary_logloss: 0.4111
# [42]	valid_0's binary_logloss: 0.410942
# [43]	valid_0's binary_logloss: 0.410771
# [44]	valid_0's binary_logloss: 0.410578
# [45]	valid_0's binary_logloss: 0.410399
# [46]	valid_0's binary_logloss: 0.410244
# [47]	valid_0's binary_logloss: 0.410095
# [48]	valid_0's binary_logloss: 0.409932
# [49]	valid_0's binary_logloss: 0.409782
# [50]	valid_0's binary_logloss: 0.409678
# [51]	valid_0's binary_logloss: 0.409479
# [52]	valid_0's binary_logloss: 0.409321
# [53]	valid_0's binary_logloss: 0.409215
# [54]	valid_0's binary_logloss: 0.40912
# [55]	valid_0's binary_logloss: 0.409028
# [56]	valid_0's binary_logloss: 0.408939
# [57]	valid_0's binary_logloss: 0.408821
# [58]	valid_0's binary_logloss: 0.408677
# [59]	valid_0's binary_logloss: 0.408572
# [60]	valid_0's binary_logloss: 0.408476
# [61]	valid_0's binary_logloss: 0.408392
# [62]	valid_0's binary_logloss: 0.408305
# [63]	valid_0's binary_logloss: 0.40822
# [64]	valid_0's binary_logloss: 0.408142
# [65]	valid_0's binary_logloss: 0.407989
# [66]	valid_0's binary_logloss: 0.407921
# [67]	valid_0's binary_logloss: 0.407832
# [68]	valid_0's binary_logloss: 0.407763
# [69]	valid_0's binary_logloss: 0.407719
# [70]	valid_0's binary_logloss: 0.407652
# [71]	valid_0's binary_logloss: 0.407594
# [72]	valid_0's binary_logloss: 0.40751
# [73]	valid_0's binary_logloss: 0.40743
# [74]	valid_0's binary_logloss: 0.407361
# [75]	valid_0's binary_logloss: 0.407249
# [76]	valid_0's binary_logloss: 0.407192
# [77]	valid_0's binary_logloss: 0.40713
# [78]	valid_0's binary_logloss: 0.407098
# [79]	valid_0's binary_logloss: 0.407028
# [80]	valid_0's binary_logloss: 0.406981
# [81]	valid_0's binary_logloss: 0.406927
# [82]	valid_0's binary_logloss: 0.40681
# [83]	valid_0's binary_logloss: 0.406762
# [84]	valid_0's binary_logloss: 0.406714
# [85]	valid_0's binary_logloss: 0.406671
# [86]	valid_0's binary_logloss: 0.406637
# [87]	valid_0's binary_logloss: 0.406598
# [88]	valid_0's binary_logloss: 0.40655
# [89]	valid_0's binary_logloss: 0.406501
# [90]	valid_0's binary_logloss: 0.406445
# [91]	valid_0's binary_logloss: 0.406408
# [92]	valid_0's binary_logloss: 0.406341
# [93]	valid_0's binary_logloss: 0.406284
# [94]	valid_0's binary_logloss: 0.406247
# [95]	valid_0's binary_logloss: 0.406204
# [96]	valid_0's binary_logloss: 0.406121
# [97]	valid_0's binary_logloss: 0.406043
# [98]	valid_0's binary_logloss: 0.406012
# [99]	valid_0's binary_logloss: 0.405957
# [100]	valid_0's binary_logloss: 0.405897
# [101]	valid_0's binary_logloss: 0.405833
# [102]	valid_0's binary_logloss: 0.405765
# [103]	valid_0's binary_logloss: 0.40573
# [104]	valid_0's binary_logloss: 0.405693
# [105]	valid_0's binary_logloss: 0.405672
# [106]	valid_0's binary_logloss: 0.405639
# [107]	valid_0's binary_logloss: 0.405624
# [108]	valid_0's binary_logloss: 0.405569
# [109]	valid_0's binary_logloss: 0.405552
# [110]	valid_0's binary_logloss: 0.405513
# [111]	valid_0's binary_logloss: 0.405481
# [112]	valid_0's binary_logloss: 0.405465
# [113]	valid_0's binary_logloss: 0.405409
# [114]	valid_0's binary_logloss: 0.405382
# [115]	valid_0's binary_logloss: 0.405321
# [116]	valid_0's binary_logloss: 0.405271
# [117]	valid_0's binary_logloss: 0.405238
# [118]	valid_0's binary_logloss: 0.405178
# [119]	valid_0's binary_logloss: 0.405159
# [120]	valid_0's binary_logloss: 0.405116
# [121]	valid_0's binary_logloss: 0.405061
# [122]	valid_0's binary_logloss: 0.405033
# [123]	valid_0's binary_logloss: 0.404991
# [124]	valid_0's binary_logloss: 0.404933
# [125]	valid_0's binary_logloss: 0.404906
# [126]	valid_0's binary_logloss: 0.404895
# [127]	valid_0's binary_logloss: 0.404863
# [128]	valid_0's binary_logloss: 0.404855
# [129]	valid_0's binary_logloss: 0.404825
# [130]	valid_0's binary_logloss: 0.404801
# [131]	valid_0's binary_logloss: 0.404744
# [132]	valid_0's binary_logloss: 0.404635
# [133]	valid_0's binary_logloss: 0.404628
# [134]	valid_0's binary_logloss: 0.404615
# [135]	valid_0's binary_logloss: 0.404561
# [136]	valid_0's binary_logloss: 0.404544
# [137]	valid_0's binary_logloss: 0.40446
# [138]	valid_0's binary_logloss: 0.40442
# [139]	valid_0's binary_logloss: 0.404406
# [140]	valid_0's binary_logloss: 0.404384
# [141]	valid_0's binary_logloss: 0.404348
# [142]	valid_0's binary_logloss: 0.404345
# [143]	valid_0's binary_logloss: 0.404337
# [144]	valid_0's binary_logloss: 0.404305
# [145]	valid_0's binary_logloss: 0.404269
# [146]	valid_0's binary_logloss: 0.404252
# [147]	valid_0's binary_logloss: 0.404231
# [148]	valid_0's binary_logloss: 0.404224
# [149]	valid_0's binary_logloss: 0.404222
# [150]	valid_0's binary_logloss: 0.404188
# [151]	valid_0's binary_logloss: 0.40416
# [152]	valid_0's binary_logloss: 0.404142
# [153]	valid_0's binary_logloss: 0.404126
# [154]	valid_0's binary_logloss: 0.404037
# [155]	valid_0's binary_logloss: 0.404003
# [156]	valid_0's binary_logloss: 0.403985
# [157]	valid_0's binary_logloss: 0.403961
# [158]	valid_0's binary_logloss: 0.403935
# [159]	valid_0's binary_logloss: 0.403909
# [160]	valid_0's binary_logloss: 0.403881
# [161]	valid_0's binary_logloss: 0.403862
# [162]	valid_0's binary_logloss: 0.40378
# [163]	valid_0's binary_logloss: 0.403758
# [164]	valid_0's binary_logloss: 0.403727
# [165]	valid_0's binary_logloss: 0.40372
# [166]	valid_0's binary_logloss: 0.403679
# [167]	valid_0's binary_logloss: 0.403674
# [168]	valid_0's binary_logloss: 0.403653
# [169]	valid_0's binary_logloss: 0.403645
# [170]	valid_0's binary_logloss: 0.403618
# [171]	valid_0's binary_logloss: 0.403589
# [172]	valid_0's binary_logloss: 0.403558
# [173]	valid_0's binary_logloss: 0.403554
# [174]	valid_0's binary_logloss: 0.40355
# [175]	valid_0's binary_logloss: 0.403548
# [176]	valid_0's binary_logloss: 0.403547
# [177]	valid_0's binary_logloss: 0.403469
# [178]	valid_0's binary_logloss: 0.403461
# [179]	valid_0's binary_logloss: 0.403453
# [180]	valid_0's binary_logloss: 0.403449
# [181]	valid_0's binary_logloss: 0.403413
# [182]	valid_0's binary_logloss: 0.40339
# [183]	valid_0's binary_logloss: 0.403363
# [184]	valid_0's binary_logloss: 0.403347
# [185]	valid_0's binary_logloss: 0.403318
# [186]	valid_0's binary_logloss: 0.403304
# [187]	valid_0's binary_logloss: 0.403277
# [188]	valid_0's binary_logloss: 0.403257
# [189]	valid_0's binary_logloss: 0.403248
# [190]	valid_0's binary_logloss: 0.403216
# [191]	valid_0's binary_logloss: 0.403151
# [192]	valid_0's binary_logloss: 0.403139
# [193]	valid_0's binary_logloss: 0.403135
# [194]	valid_0's binary_logloss: 0.403124
# [195]	valid_0's binary_logloss: 0.403119
# [196]	valid_0's binary_logloss: 0.403102
# [197]	valid_0's binary_logloss: 0.403084
# [198]	valid_0's binary_logloss: 0.403069
# [199]	valid_0's binary_logloss: 0.403069
# [200]	valid_0's binary_logloss: 0.403067
# [201]	valid_0's binary_logloss: 0.403056
# [202]	valid_0's binary_logloss: 0.403049
# [203]	valid_0's binary_logloss: 0.403048
# [204]	valid_0's binary_logloss: 0.403032
# [205]	valid_0's binary_logloss: 0.403028
# [206]	valid_0's binary_logloss: 0.403024
# [207]	valid_0's binary_logloss: 0.40302
# [208]	valid_0's binary_logloss: 0.403011
# [209]	valid_0's binary_logloss: 0.403013
# [210]	valid_0's binary_logloss: 0.403
# [211]	valid_0's binary_logloss: 0.402986
# [212]	valid_0's binary_logloss: 0.402985
# [213]	valid_0's binary_logloss: 0.402982
# [214]	valid_0's binary_logloss: 0.402976
# [215]	valid_0's binary_logloss: 0.402961
# [216]	valid_0's binary_logloss: 0.402947
# [217]	valid_0's binary_logloss: 0.402929
# [218]	valid_0's binary_logloss: 0.402897
# [219]	valid_0's binary_logloss: 0.402896
# [220]	valid_0's binary_logloss: 0.402881
# [221]	valid_0's binary_logloss: 0.402879
# [222]	valid_0's binary_logloss: 0.402868
# [223]	valid_0's binary_logloss: 0.40285
# [224]	valid_0's binary_logloss: 0.402847
# [225]	valid_0's binary_logloss: 0.402814
# [226]	valid_0's binary_logloss: 0.402805
# [227]	valid_0's binary_logloss: 0.402785
# [228]	valid_0's binary_logloss: 0.40278
# [229]	valid_0's binary_logloss: 0.402726
# [230]	valid_0's binary_logloss: 0.402725
# [231]	valid_0's binary_logloss: 0.402722
# [232]	valid_0's binary_logloss: 0.402715
# [233]	valid_0's binary_logloss: 0.402714
# [234]	valid_0's binary_logloss: 0.402687
# [235]	valid_0's binary_logloss: 0.402658
# [236]	valid_0's binary_logloss: 0.402606
# [237]	valid_0's binary_logloss: 0.402592
# [238]	valid_0's binary_logloss: 0.402583
# [239]	valid_0's binary_logloss: 0.402566
# [240]	valid_0's binary_logloss: 0.402555
# [241]	valid_0's binary_logloss: 0.402557
# [242]	valid_0's binary_logloss: 0.402553
# [243]	valid_0's binary_logloss: 0.402556
# [244]	valid_0's binary_logloss: 0.402528
# [245]	valid_0's binary_logloss: 0.402485
# [246]	valid_0's binary_logloss: 0.40244
# [247]	valid_0's binary_logloss: 0.402413
# [248]	valid_0's binary_logloss: 0.402397
# [249]	valid_0's binary_logloss: 0.40238
# [250]	valid_0's binary_logloss: 0.40236
# [251]	valid_0's binary_logloss: 0.402351
# [252]	valid_0's binary_logloss: 0.402337
# [253]	valid_0's binary_logloss: 0.402335
# [254]	valid_0's binary_logloss: 0.4023
# [255]	valid_0's binary_logloss: 0.402287
# [256]	valid_0's binary_logloss: 0.402265
# [257]	valid_0's binary_logloss: 0.402245
# [258]	valid_0's binary_logloss: 0.402236
# [259]	valid_0's binary_logloss: 0.402225
# [260]	valid_0's binary_logloss: 0.402218
# [261]	valid_0's binary_logloss: 0.402209
# [262]	valid_0's binary_logloss: 0.402196
# [263]	valid_0's binary_logloss: 0.402191
# [264]	valid_0's binary_logloss: 0.402184
# [265]	valid_0's binary_logloss: 0.402179
# [266]	valid_0's binary_logloss: 0.402159
# [267]	valid_0's binary_logloss: 0.402158
# [268]	valid_0's binary_logloss: 0.402156
# [269]	valid_0's binary_logloss: 0.402101
# [270]	valid_0's binary_logloss: 0.402088
# [271]	valid_0's binary_logloss: 0.402088
# [272]	valid_0's binary_logloss: 0.402083
# [273]	valid_0's binary_logloss: 0.402081
# [274]	valid_0's binary_logloss: 0.402068
# [275]	valid_0's binary_logloss: 0.402042
# [276]	valid_0's binary_logloss: 0.402029
# [277]	valid_0's binary_logloss: 0.402016
# [278]	valid_0's binary_logloss: 0.402015
# [279]	valid_0's binary_logloss: 0.402007
# [280]	valid_0's binary_logloss: 0.402009
# [281]	valid_0's binary_logloss: 0.401981
# [282]	valid_0's binary_logloss: 0.401981
# [283]	valid_0's binary_logloss: 0.401978
# [284]	valid_0's binary_logloss: 0.401948
# [285]	valid_0's binary_logloss: 0.401932
# [286]	valid_0's binary_logloss: 0.401927
# [287]	valid_0's binary_logloss: 0.401925
# [288]	valid_0's binary_logloss: 0.401896
# [289]	valid_0's binary_logloss: 0.401882
# [290]	valid_0's binary_logloss: 0.401847
# [291]	valid_0's binary_logloss: 0.401837
# [292]	valid_0's binary_logloss: 0.401834
# [293]	valid_0's binary_logloss: 0.401825
# [294]	valid_0's binary_logloss: 0.401822
# [295]	valid_0's binary_logloss: 0.401816
# [296]	valid_0's binary_logloss: 0.4018
# [297]	valid_0's binary_logloss: 0.401788
# [298]	valid_0's binary_logloss: 0.401782
# [299]	valid_0's binary_logloss: 0.401779
# [300]	valid_0's binary_logloss: 0.401762
# [301]	valid_0's binary_logloss: 0.401764
# [302]	valid_0's binary_logloss: 0.401769
# [303]	valid_0's binary_logloss: 0.401766
# [304]	valid_0's binary_logloss: 0.401734
# [305]	valid_0's binary_logloss: 0.401732
# [306]	valid_0's binary_logloss: 0.401726
# [307]	valid_0's binary_logloss: 0.401722
# [308]	valid_0's binary_logloss: 0.401721
# [309]	valid_0's binary_logloss: 0.401719
# [310]	valid_0's binary_logloss: 0.401707
# [311]	valid_0's binary_logloss: 0.401693
# [312]	valid_0's binary_logloss: 0.401694
# [313]	valid_0's binary_logloss: 0.401681
# [314]	valid_0's binary_logloss: 0.401674
# [315]	valid_0's binary_logloss: 0.401674
# [316]	valid_0's binary_logloss: 0.401675
# [317]	valid_0's binary_logloss: 0.401678
# [318]	valid_0's binary_logloss: 0.401677
# [319]	valid_0's binary_logloss: 0.40167
# [320]	valid_0's binary_logloss: 0.401667
# [321]	valid_0's binary_logloss: 0.401652
# [322]	valid_0's binary_logloss: 0.401618
# [323]	valid_0's binary_logloss: 0.401604
# [324]	valid_0's binary_logloss: 0.401581
# [325]	valid_0's binary_logloss: 0.401582
# [326]	valid_0's binary_logloss: 0.401581
# [327]	valid_0's binary_logloss: 0.401565
# [328]	valid_0's binary_logloss: 0.401553
# [329]	valid_0's binary_logloss: 0.40153
# [330]	valid_0's binary_logloss: 0.401531
# [331]	valid_0's binary_logloss: 0.401524
# [332]	valid_0's binary_logloss: 0.40149
# [333]	valid_0's binary_logloss: 0.401476
# [334]	valid_0's binary_logloss: 0.401464
# [335]	valid_0's binary_logloss: 0.401458
# [336]	valid_0's binary_logloss: 0.401451
# [337]	valid_0's binary_logloss: 0.40143
# [338]	valid_0's binary_logloss: 0.401404
# [339]	valid_0's binary_logloss: 0.4014
# [340]	valid_0's binary_logloss: 0.401401
# [341]	valid_0's binary_logloss: 0.401373
# [342]	valid_0's binary_logloss: 0.401354
# [343]	valid_0's binary_logloss: 0.401355
# [344]	valid_0's binary_logloss: 0.401357
# [345]	valid_0's binary_logloss: 0.401346
# [346]	valid_0's binary_logloss: 0.401342
# [347]	valid_0's binary_logloss: 0.401346
# [348]	valid_0's binary_logloss: 0.401327
# [349]	valid_0's binary_logloss: 0.401312
# [350]	valid_0's binary_logloss: 0.401307
# [351]	valid_0's binary_logloss: 0.401291
# [352]	valid_0's binary_logloss: 0.401289
# [353]	valid_0's binary_logloss: 0.401285
# [354]	valid_0's binary_logloss: 0.401271
# [355]	valid_0's binary_logloss: 0.401268
# [356]	valid_0's binary_logloss: 0.401266
# [357]	valid_0's binary_logloss: 0.401264
# [358]	valid_0's binary_logloss: 0.401265
# [359]	valid_0's binary_logloss: 0.401247
# [360]	valid_0's binary_logloss: 0.401231
# [361]	valid_0's binary_logloss: 0.401212
# [362]	valid_0's binary_logloss: 0.40121
# [363]	valid_0's binary_logloss: 0.401183
# [364]	valid_0's binary_logloss: 0.40118
# [365]	valid_0's binary_logloss: 0.401153
# [366]	valid_0's binary_logloss: 0.401154
# [367]	valid_0's binary_logloss: 0.401139
# [368]	valid_0's binary_logloss: 0.401134
# [369]	valid_0's binary_logloss: 0.401132
# [370]	valid_0's binary_logloss: 0.401119
# [371]	valid_0's binary_logloss: 0.401112
# [372]	valid_0's binary_logloss: 0.401112
# [373]	valid_0's binary_logloss: 0.401111
# [374]	valid_0's binary_logloss: 0.401101
# [375]	valid_0's binary_logloss: 0.401084
# [376]	valid_0's binary_logloss: 0.401074
# [377]	valid_0's binary_logloss: 0.401064
# [378]	valid_0's binary_logloss: 0.401056
# [379]	valid_0's binary_logloss: 0.401055
# [380]	valid_0's binary_logloss: 0.401039
# [381]	valid_0's binary_logloss: 0.401029
# [382]	valid_0's binary_logloss: 0.401025
# [383]	valid_0's binary_logloss: 0.40102
# [384]	valid_0's binary_logloss: 0.401022
# [385]	valid_0's binary_logloss: 0.401022
# [386]	valid_0's binary_logloss: 0.401002
# [387]	valid_0's binary_logloss: 0.400998
# [388]	valid_0's binary_logloss: 0.400994
# [389]	valid_0's binary_logloss: 0.400962
# [390]	valid_0's binary_logloss: 0.400957
# [391]	valid_0's binary_logloss: 0.400954
# [392]	valid_0's binary_logloss: 0.400949
# [393]	valid_0's binary_logloss: 0.400937
# [394]	valid_0's binary_logloss: 0.400932
# [395]	valid_0's binary_logloss: 0.400933
# [396]	valid_0's binary_logloss: 0.400927
# [397]	valid_0's binary_logloss: 0.400927
# [398]	valid_0's binary_logloss: 0.400927
# [399]	valid_0's binary_logloss: 0.400922
# [400]	valid_0's binary_logloss: 0.400921
# [401]	valid_0's binary_logloss: 0.400899
# [402]	valid_0's binary_logloss: 0.40089
# [403]	valid_0's binary_logloss: 0.400889
# [404]	valid_0's binary_logloss: 0.400884
# [405]	valid_0's binary_logloss: 0.400881
# [406]	valid_0's binary_logloss: 0.400848
# [407]	valid_0's binary_logloss: 0.400825
# [408]	valid_0's binary_logloss: 0.400825
# [409]	valid_0's binary_logloss: 0.400824
# [410]	valid_0's binary_logloss: 0.400823
# [411]	valid_0's binary_logloss: 0.400823
# [412]	valid_0's binary_logloss: 0.400819
# [413]	valid_0's binary_logloss: 0.400802
# [414]	valid_0's binary_logloss: 0.400784
# [415]	valid_0's binary_logloss: 0.400785
# [416]	valid_0's binary_logloss: 0.400786
# [417]	valid_0's binary_logloss: 0.400782
# [418]	valid_0's binary_logloss: 0.400773
# [419]	valid_0's binary_logloss: 0.400766
# [420]	valid_0's binary_logloss: 0.400768
# [421]	valid_0's binary_logloss: 0.400762
# [422]	valid_0's binary_logloss: 0.40076
# [423]	valid_0's binary_logloss: 0.400748
# [424]	valid_0's binary_logloss: 0.400743
# [425]	valid_0's binary_logloss: 0.400732
# [426]	valid_0's binary_logloss: 0.400731
# [427]	valid_0's binary_logloss: 0.400731
# [428]	valid_0's binary_logloss: 0.400709
# [429]	valid_0's binary_logloss: 0.400703
# [430]	valid_0's binary_logloss: 0.400699
# [431]	valid_0's binary_logloss: 0.400697
# [432]	valid_0's binary_logloss: 0.400682
# [433]	valid_0's binary_logloss: 0.400679
# [434]	valid_0's binary_logloss: 0.400682
# [435]	valid_0's binary_logloss: 0.400674
# [436]	valid_0's binary_logloss: 0.400671
# [437]	valid_0's binary_logloss: 0.400669
# [438]	valid_0's binary_logloss: 0.400655
# [439]	valid_0's binary_logloss: 0.400644
# [440]	valid_0's binary_logloss: 0.400642
# [441]	valid_0's binary_logloss: 0.400644
# [442]	valid_0's binary_logloss: 0.400644
# [443]	valid_0's binary_logloss: 0.400631
# [444]	valid_0's binary_logloss: 0.400627
# [445]	valid_0's binary_logloss: 0.400626
# [446]	valid_0's binary_logloss: 0.400623
# [447]	valid_0's binary_logloss: 0.400619
# [448]	valid_0's binary_logloss: 0.400607
# [449]	valid_0's binary_logloss: 0.400606
# [450]	valid_0's binary_logloss: 0.40059
# [451]	valid_0's binary_logloss: 0.400586
# [452]	valid_0's binary_logloss: 0.400583
# [453]	valid_0's binary_logloss: 0.400582
# [454]	valid_0's binary_logloss: 0.400571
# [455]	valid_0's binary_logloss: 0.400557
# [456]	valid_0's binary_logloss: 0.400558
# [457]	valid_0's binary_logloss: 0.400559
# [458]	valid_0's binary_logloss: 0.40056
# [459]	valid_0's binary_logloss: 0.400561
# [460]	valid_0's binary_logloss: 0.400556
# [461]	valid_0's binary_logloss: 0.400553
# [462]	valid_0's binary_logloss: 0.400548
# [463]	valid_0's binary_logloss: 0.400547
# [464]	valid_0's binary_logloss: 0.400545
# [465]	valid_0's binary_logloss: 0.400538
# [466]	valid_0's binary_logloss: 0.400542
# [467]	valid_0's binary_logloss: 0.400536
# [468]	valid_0's binary_logloss: 0.400537
# [469]	valid_0's binary_logloss: 0.400536
# [470]	valid_0's binary_logloss: 0.400524
# [471]	valid_0's binary_logloss: 0.400518
# [472]	valid_0's binary_logloss: 0.400519
# [473]	valid_0's binary_logloss: 0.400513
# [474]	valid_0's binary_logloss: 0.400511
# [475]	valid_0's binary_logloss: 0.400501
# [476]	valid_0's binary_logloss: 0.400504
# [477]	valid_0's binary_logloss: 0.400506
# [478]	valid_0's binary_logloss: 0.400493
# [479]	valid_0's binary_logloss: 0.400484
# [480]	valid_0's binary_logloss: 0.400478
# [481]	valid_0's binary_logloss: 0.400467
# [482]	valid_0's binary_logloss: 0.400465
# [483]	valid_0's binary_logloss: 0.400464
# [484]	valid_0's binary_logloss: 0.400464
# [485]	valid_0's binary_logloss: 0.400456
# [486]	valid_0's binary_logloss: 0.400455
# [487]	valid_0's binary_logloss: 0.400447
# [488]	valid_0's binary_logloss: 0.400448
# [489]	valid_0's binary_logloss: 0.40041
# [490]	valid_0's binary_logloss: 0.400387
# [491]	valid_0's binary_logloss: 0.400387
# [492]	valid_0's binary_logloss: 0.400375
# [493]	valid_0's binary_logloss: 0.400373
# [494]	valid_0's binary_logloss: 0.400376
# [495]	valid_0's binary_logloss: 0.400374
# [496]	valid_0's binary_logloss: 0.400357
# [497]	valid_0's binary_logloss: 0.400355
# [498]	valid_0's binary_logloss: 0.400346
# [499]	valid_0's binary_logloss: 0.400344
# [500]	valid_0's binary_logloss: 0.400336
# [501]	valid_0's binary_logloss: 0.400322
# [502]	valid_0's binary_logloss: 0.400319
# [503]	valid_0's binary_logloss: 0.400319
# [504]	valid_0's binary_logloss: 0.400318
# [505]	valid_0's binary_logloss: 0.400299
# [506]	valid_0's binary_logloss: 0.4003
# [507]	valid_0's binary_logloss: 0.400299
# [508]	valid_0's binary_logloss: 0.400294
# [509]	valid_0's binary_logloss: 0.40029
# [510]	valid_0's binary_logloss: 0.400285
# [511]	valid_0's binary_logloss: 0.400282
# [512]	valid_0's binary_logloss: 0.400284
# [513]	valid_0's binary_logloss: 0.400285
# [514]	valid_0's binary_logloss: 0.400276
# [515]	valid_0's binary_logloss: 0.400258
# [516]	valid_0's binary_logloss: 0.400255
# [517]	valid_0's binary_logloss: 0.400259
# [518]	valid_0's binary_logloss: 0.400253
# [519]	valid_0's binary_logloss: 0.400255
# [520]	valid_0's binary_logloss: 0.400251
# [521]	valid_0's binary_logloss: 0.400249
# [522]	valid_0's binary_logloss: 0.40025
# [523]	valid_0's binary_logloss: 0.400227
# [524]	valid_0's binary_logloss: 0.400221
# [525]	valid_0's binary_logloss: 0.400214
# [526]	valid_0's binary_logloss: 0.400212
# [527]	valid_0's binary_logloss: 0.400199
# [528]	valid_0's binary_logloss: 0.400199
# [529]	valid_0's binary_logloss: 0.400195
# [530]	valid_0's binary_logloss: 0.400191
# [531]	valid_0's binary_logloss: 0.400187
# [532]	valid_0's binary_logloss: 0.400178
# [533]	valid_0's binary_logloss: 0.40017
# [534]	valid_0's binary_logloss: 0.400161
# [535]	valid_0's binary_logloss: 0.400147
# [536]	valid_0's binary_logloss: 0.400152
# [537]	valid_0's binary_logloss: 0.40015
# [538]	valid_0's binary_logloss: 0.400151
# [539]	valid_0's binary_logloss: 0.400151
# [540]	valid_0's binary_logloss: 0.400151
# [541]	valid_0's binary_logloss: 0.400133
# [542]	valid_0's binary_logloss: 0.400129
# [543]	valid_0's binary_logloss: 0.400133
# [544]	valid_0's binary_logloss: 0.400128
# [545]	valid_0's binary_logloss: 0.400126
# [546]	valid_0's binary_logloss: 0.400127
# [547]	valid_0's binary_logloss: 0.400121
# [548]	valid_0's binary_logloss: 0.400107
# [549]	valid_0's binary_logloss: 0.40011
# [550]	valid_0's binary_logloss: 0.400096
# [551]	valid_0's binary_logloss: 0.400097
# [552]	valid_0's binary_logloss: 0.4001
# [553]	valid_0's binary_logloss: 0.400091
# [554]	valid_0's binary_logloss: 0.400089
# [555]	valid_0's binary_logloss: 0.400089
# [556]	valid_0's binary_logloss: 0.400082
# [557]	valid_0's binary_logloss: 0.400081
# [558]	valid_0's binary_logloss: 0.400083
# [559]	valid_0's binary_logloss: 0.400078
# [560]	valid_0's binary_logloss: 0.400081
# [561]	valid_0's binary_logloss: 0.400083
# [562]	valid_0's binary_logloss: 0.400077
# [563]	valid_0's binary_logloss: 0.400064
# [564]	valid_0's binary_logloss: 0.400065
# [565]	valid_0's binary_logloss: 0.400066
# [566]	valid_0's binary_logloss: 0.400066
# [567]	valid_0's binary_logloss: 0.400063
# [568]	valid_0's binary_logloss: 0.400052
# [569]	valid_0's binary_logloss: 0.400054
# [570]	valid_0's binary_logloss: 0.400054
# [571]	valid_0's binary_logloss: 0.400048
# [572]	valid_0's binary_logloss: 0.400041
# [573]	valid_0's binary_logloss: 0.400039
# [574]	valid_0's binary_logloss: 0.400032
# [575]	valid_0's binary_logloss: 0.400023
# [576]	valid_0's binary_logloss: 0.400019
# [577]	valid_0's binary_logloss: 0.400013
# [578]	valid_0's binary_logloss: 0.399998
# [579]	valid_0's binary_logloss: 0.399997
# [580]	valid_0's binary_logloss: 0.399995
# [581]	valid_0's binary_logloss: 0.399996
# [582]	valid_0's binary_logloss: 0.4
# [583]	valid_0's binary_logloss: 0.400005
# [584]	valid_0's binary_logloss: 0.400006
# [585]	valid_0's binary_logloss: 0.400004
# [586]	valid_0's binary_logloss: 0.399998
# [587]	valid_0's binary_logloss: 0.399991
# [588]	valid_0's binary_logloss: 0.399994
# [589]	valid_0's binary_logloss: 0.399985
# [590]	valid_0's binary_logloss: 0.399984
# [591]	valid_0's binary_logloss: 0.399979
# [592]	valid_0's binary_logloss: 0.39998
# [593]	valid_0's binary_logloss: 0.39998
# [594]	valid_0's binary_logloss: 0.399984
# [595]	valid_0's binary_logloss: 0.399984
# [596]	valid_0's binary_logloss: 0.399967
# [597]	valid_0's binary_logloss: 0.399953
# [598]	valid_0's binary_logloss: 0.399952
# [599]	valid_0's binary_logloss: 0.399955
# [600]	valid_0's binary_logloss: 0.399953
# [601]	valid_0's binary_logloss: 0.399947
# [602]	valid_0's binary_logloss: 0.399948
# [603]	valid_0's binary_logloss: 0.399946
# [604]	valid_0's binary_logloss: 0.399946
# [605]	valid_0's binary_logloss: 0.399948
# [606]	valid_0's binary_logloss: 0.399944
# [607]	valid_0's binary_logloss: 0.39994
# [608]	valid_0's binary_logloss: 0.399942
# [609]	valid_0's binary_logloss: 0.399946
# [610]	valid_0's binary_logloss: 0.399942
# [611]	valid_0's binary_logloss: 0.399943
# [612]	valid_0's binary_logloss: 0.399939
# [613]	valid_0's binary_logloss: 0.399937
# [614]	valid_0's binary_logloss: 0.399938
# [615]	valid_0's binary_logloss: 0.399937
# [616]	valid_0's binary_logloss: 0.399935
# [617]	valid_0's binary_logloss: 0.399933
# [618]	valid_0's binary_logloss: 0.39993
# [619]	valid_0's binary_logloss: 0.399926
# [620]	valid_0's binary_logloss: 0.399926
# [621]	valid_0's binary_logloss: 0.399927
# [622]	valid_0's binary_logloss: 0.399921
# [623]	valid_0's binary_logloss: 0.399921
# [624]	valid_0's binary_logloss: 0.399916
# [625]	valid_0's binary_logloss: 0.399912
# [626]	valid_0's binary_logloss: 0.399913
# [627]	valid_0's binary_logloss: 0.399912
# [628]	valid_0's binary_logloss: 0.399911
# [629]	valid_0's binary_logloss: 0.399911
# [630]	valid_0's binary_logloss: 0.399911
# [631]	valid_0's binary_logloss: 0.399914
# [632]	valid_0's binary_logloss: 0.399917
# [633]	valid_0's binary_logloss: 0.399915
# [634]	valid_0's binary_logloss: 0.399916
# [635]	valid_0's binary_logloss: 0.399919
# [636]	valid_0's binary_logloss: 0.399919
# [637]	valid_0's binary_logloss: 0.399918
# [638]	valid_0's binary_logloss: 0.39992
# [639]	valid_0's binary_logloss: 0.399916
# [640]	valid_0's binary_logloss: 0.39991
# [641]	valid_0's binary_logloss: 0.399904
# [642]	valid_0's binary_logloss: 0.399906
# [643]	valid_0's binary_logloss: 0.399905
# [644]	valid_0's binary_logloss: 0.399895
# [645]	valid_0's binary_logloss: 0.399881
# [646]	valid_0's binary_logloss: 0.399879
# [647]	valid_0's binary_logloss: 0.399881
# [648]	valid_0's binary_logloss: 0.399881
# [649]	valid_0's binary_logloss: 0.399861
# [650]	valid_0's binary_logloss: 0.399849
# [651]	valid_0's binary_logloss: 0.399845
# [652]	valid_0's binary_logloss: 0.399844
# [653]	valid_0's binary_logloss: 0.399835
# [654]	valid_0's binary_logloss: 0.399824
# [655]	valid_0's binary_logloss: 0.399827
# [656]	valid_0's binary_logloss: 0.399828
# [657]	valid_0's binary_logloss: 0.399822
# [658]	valid_0's binary_logloss: 0.399823
# [659]	valid_0's binary_logloss: 0.399823
# [660]	valid_0's binary_logloss: 0.399824
# [661]	valid_0's binary_logloss: 0.399826
# [662]	valid_0's binary_logloss: 0.399825
# [663]	valid_0's binary_logloss: 0.399819
# [664]	valid_0's binary_logloss: 0.399821
# [665]	valid_0's binary_logloss: 0.399821
# [666]	valid_0's binary_logloss: 0.399822
# [667]	valid_0's binary_logloss: 0.399808
# [668]	valid_0's binary_logloss: 0.399806
# [669]	valid_0's binary_logloss: 0.399802
# [670]	valid_0's binary_logloss: 0.399783
# [671]	valid_0's binary_logloss: 0.399782
# [672]	valid_0's binary_logloss: 0.399778
# [673]	valid_0's binary_logloss: 0.399769
# [674]	valid_0's binary_logloss: 0.399758
# [675]	valid_0's binary_logloss: 0.399758
# [676]	valid_0's binary_logloss: 0.399753
# [677]	valid_0's binary_logloss: 0.399753
# [678]	valid_0's binary_logloss: 0.399753
# [679]	valid_0's binary_logloss: 0.399749
# [680]	valid_0's binary_logloss: 0.399749
# [681]	valid_0's binary_logloss: 0.399748
# [682]	valid_0's binary_logloss: 0.399749
# [683]	valid_0's binary_logloss: 0.399743
# [684]	valid_0's binary_logloss: 0.39974
# [685]	valid_0's binary_logloss: 0.399738
# [686]	valid_0's binary_logloss: 0.399735
# [687]	valid_0's binary_logloss: 0.399736
# [688]	valid_0's binary_logloss: 0.399739
# [689]	valid_0's binary_logloss: 0.399736
# [690]	valid_0's binary_logloss: 0.399738
# [691]	valid_0's binary_logloss: 0.399735
# [692]	valid_0's binary_logloss: 0.399736
# [693]	valid_0's binary_logloss: 0.399737
# [694]	valid_0's binary_logloss: 0.399738
# [695]	valid_0's binary_logloss: 0.399737
# [696]	valid_0's binary_logloss: 0.399726
# [697]	valid_0's binary_logloss: 0.399729
# [698]	valid_0's binary_logloss: 0.399729
# [699]	valid_0's binary_logloss: 0.399734
# [700]	valid_0's binary_logloss: 0.399737
# [701]	valid_0's binary_logloss: 0.399731
# [702]	valid_0's binary_logloss: 0.399733
# [703]	valid_0's binary_logloss: 0.399729
# [704]	valid_0's binary_logloss: 0.399732
# [705]	valid_0's binary_logloss: 0.399727
# [706]	valid_0's binary_logloss: 0.399716
# [707]	valid_0's binary_logloss: 0.39972
# [708]	valid_0's binary_logloss: 0.399719
# [709]	valid_0's binary_logloss: 0.399722
# [710]	valid_0's binary_logloss: 0.39972
# [711]	valid_0's binary_logloss: 0.399721
# [712]	valid_0's binary_logloss: 0.399723
# [713]	valid_0's binary_logloss: 0.399723
# [714]	valid_0's binary_logloss: 0.399722
# [715]	valid_0's binary_logloss: 0.399712
# [716]	valid_0's binary_logloss: 0.399713
# [717]	valid_0's binary_logloss: 0.399717
# [718]	valid_0's binary_logloss: 0.399716
# [719]	valid_0's binary_logloss: 0.39972
# [720]	valid_0's binary_logloss: 0.399721
# [721]	valid_0's binary_logloss: 0.399721
# [722]	valid_0's binary_logloss: 0.399721
# [723]	valid_0's binary_logloss: 0.399717
# [724]	valid_0's binary_logloss: 0.39972
# [725]	valid_0's binary_logloss: 0.399715
# [726]	valid_0's binary_logloss: 0.399704
# [727]	valid_0's binary_logloss: 0.399701
# [728]	valid_0's binary_logloss: 0.399698
# [729]	valid_0's binary_logloss: 0.399697
# [730]	valid_0's binary_logloss: 0.399695
# [731]	valid_0's binary_logloss: 0.399691
# [732]	valid_0's binary_logloss: 0.399687
# [733]	valid_0's binary_logloss: 0.399686
# [734]	valid_0's binary_logloss: 0.399686
# [735]	valid_0's binary_logloss: 0.399682
# [736]	valid_0's binary_logloss: 0.399683
# [737]	valid_0's binary_logloss: 0.39968
# [738]	valid_0's binary_logloss: 0.399679
# [739]	valid_0's binary_logloss: 0.39968
# [740]	valid_0's binary_logloss: 0.399683
# [741]	valid_0's binary_logloss: 0.399687
# [742]	valid_0's binary_logloss: 0.399689
# [743]	valid_0's binary_logloss: 0.399688
# [744]	valid_0's binary_logloss: 0.399688
# [745]	valid_0's binary_logloss: 0.399689
# [746]	valid_0's binary_logloss: 0.399684
# [747]	valid_0's binary_logloss: 0.399687
# [748]	valid_0's binary_logloss: 0.399674
# [749]	valid_0's binary_logloss: 0.399665
# [750]	valid_0's binary_logloss: 0.399666
# [751]	valid_0's binary_logloss: 0.399659
# [752]	valid_0's binary_logloss: 0.399659
# [753]	valid_0's binary_logloss: 0.399659
# [754]	valid_0's binary_logloss: 0.399657
# [755]	valid_0's binary_logloss: 0.399655
# [756]	valid_0's binary_logloss: 0.39965
# [757]	valid_0's binary_logloss: 0.399654
# [758]	valid_0's binary_logloss: 0.399648
# [759]	valid_0's binary_logloss: 0.399647
# [760]	valid_0's binary_logloss: 0.399648
# [761]	valid_0's binary_logloss: 0.399643
# [762]	valid_0's binary_logloss: 0.399643
# [763]	valid_0's binary_logloss: 0.399642
# [764]	valid_0's binary_logloss: 0.399644
# [765]	valid_0's binary_logloss: 0.399642
# [766]	valid_0's binary_logloss: 0.399637
# [767]	valid_0's binary_logloss: 0.399639
# [768]	valid_0's binary_logloss: 0.399633
# [769]	valid_0's binary_logloss: 0.399638
# [770]	valid_0's binary_logloss: 0.399635
# [771]	valid_0's binary_logloss: 0.399638
# [772]	valid_0's binary_logloss: 0.399638
# [773]	valid_0's binary_logloss: 0.399635
# [774]	valid_0's binary_logloss: 0.399632
# [775]	valid_0's binary_logloss: 0.399635
# [776]	valid_0's binary_logloss: 0.399635
# [777]	valid_0's binary_logloss: 0.399631
# [778]	valid_0's binary_logloss: 0.399634
# [779]	valid_0's binary_logloss: 0.399635
# [780]	valid_0's binary_logloss: 0.399636
# [781]	valid_0's binary_logloss: 0.399623
# [782]	valid_0's binary_logloss: 0.399621
# [783]	valid_0's binary_logloss: 0.399619
# [784]	valid_0's binary_logloss: 0.399619
# [785]	valid_0's binary_logloss: 0.399616
# [786]	valid_0's binary_logloss: 0.399608
# [787]	valid_0's binary_logloss: 0.399606
# [788]	valid_0's binary_logloss: 0.399604
# [789]	valid_0's binary_logloss: 0.399609
# [790]	valid_0's binary_logloss: 0.399605
# [791]	valid_0's binary_logloss: 0.399601
# [792]	valid_0's binary_logloss: 0.399602
# [793]	valid_0's binary_logloss: 0.399604
# [794]	valid_0's binary_logloss: 0.399606
# [795]	valid_0's binary_logloss: 0.399605
# [796]	valid_0's binary_logloss: 0.399607
# [797]	valid_0's binary_logloss: 0.399609
# [798]	valid_0's binary_logloss: 0.399601
# [799]	valid_0's binary_logloss: 0.399594
# [800]	valid_0's binary_logloss: 0.399588
# [801]	valid_0's binary_logloss: 0.399585
# [802]	valid_0's binary_logloss: 0.399585
# [803]	valid_0's binary_logloss: 0.399579
# [804]	valid_0's binary_logloss: 0.39958
# [805]	valid_0's binary_logloss: 0.399582
# [806]	valid_0's binary_logloss: 0.399575
# [807]	valid_0's binary_logloss: 0.399574
# [808]	valid_0's binary_logloss: 0.399561
# [809]	valid_0's binary_logloss: 0.399562
# [810]	valid_0's binary_logloss: 0.399563
# [811]	valid_0's binary_logloss: 0.399555
# [812]	valid_0's binary_logloss: 0.399556
# [813]	valid_0's binary_logloss: 0.39955
# [814]	valid_0's binary_logloss: 0.399549
# [815]	valid_0's binary_logloss: 0.39955
# [816]	valid_0's binary_logloss: 0.399548
# [817]	valid_0's binary_logloss: 0.399547
# [818]	valid_0's binary_logloss: 0.399537
# [819]	valid_0's binary_logloss: 0.399537
# [820]	valid_0's binary_logloss: 0.399536
# [821]	valid_0's binary_logloss: 0.399533
# [822]	valid_0's binary_logloss: 0.399536
# [823]	valid_0's binary_logloss: 0.399533
# [824]	valid_0's binary_logloss: 0.39953
# [825]	valid_0's binary_logloss: 0.39953
# [826]	valid_0's binary_logloss: 0.399538
# [827]	valid_0's binary_logloss: 0.39954
# [828]	valid_0's binary_logloss: 0.399538
# [829]	valid_0's binary_logloss: 0.399536
# [830]	valid_0's binary_logloss: 0.399536
# [831]	valid_0's binary_logloss: 0.399536
# [832]	valid_0's binary_logloss: 0.399533
# [833]	valid_0's binary_logloss: 0.399539
# [834]	valid_0's binary_logloss: 0.399531
# [835]	valid_0's binary_logloss: 0.399522
# [836]	valid_0's binary_logloss: 0.399523
# [837]	valid_0's binary_logloss: 0.399517
# [838]	valid_0's binary_logloss: 0.399516
# [839]	valid_0's binary_logloss: 0.399514
# [840]	valid_0's binary_logloss: 0.39951
# [841]	valid_0's binary_logloss: 0.399511
# [842]	valid_0's binary_logloss: 0.399508
# [843]	valid_0's binary_logloss: 0.399509
# [844]	valid_0's binary_logloss: 0.399513
# [845]	valid_0's binary_logloss: 0.39951
# [846]	valid_0's binary_logloss: 0.399509
# [847]	valid_0's binary_logloss: 0.399511
# [848]	valid_0's binary_logloss: 0.399511
# [849]	valid_0's binary_logloss: 0.399511
# [850]	valid_0's binary_logloss: 0.399506
# [851]	valid_0's binary_logloss: 0.399505
# [852]	valid_0's binary_logloss: 0.399505
# [853]	valid_0's binary_logloss: 0.399498
# [854]	valid_0's binary_logloss: 0.399497
# [855]	valid_0's binary_logloss: 0.399492
# [856]	valid_0's binary_logloss: 0.399487
# [857]	valid_0's binary_logloss: 0.399488
# [858]	valid_0's binary_logloss: 0.399494
# [859]	valid_0's binary_logloss: 0.399495
# [860]	valid_0's binary_logloss: 0.399496
# [861]	valid_0's binary_logloss: 0.399496
# [862]	valid_0's binary_logloss: 0.399488
# [863]	valid_0's binary_logloss: 0.39949
# [864]	valid_0's binary_logloss: 0.399489
# [865]	valid_0's binary_logloss: 0.399484
# [866]	valid_0's binary_logloss: 0.399483
# [867]	valid_0's binary_logloss: 0.399485
# [868]	valid_0's binary_logloss: 0.399476
# [869]	valid_0's binary_logloss: 0.399479
# [870]	valid_0's binary_logloss: 0.399478
# [871]	valid_0's binary_logloss: 0.399468
# [872]	valid_0's binary_logloss: 0.39946
# [873]	valid_0's binary_logloss: 0.399455
# [874]	valid_0's binary_logloss: 0.399446
# [875]	valid_0's binary_logloss: 0.399442
# [876]	valid_0's binary_logloss: 0.399438
# [877]	valid_0's binary_logloss: 0.399437
# [878]	valid_0's binary_logloss: 0.399436
# [879]	valid_0's binary_logloss: 0.399435
# [880]	valid_0's binary_logloss: 0.399432
# [881]	valid_0's binary_logloss: 0.399417
# [882]	valid_0's binary_logloss: 0.399416
# [883]	valid_0's binary_logloss: 0.39942
# [884]	valid_0's binary_logloss: 0.399414
# [885]	valid_0's binary_logloss: 0.399415
# [886]	valid_0's binary_logloss: 0.399415
# [887]	valid_0's binary_logloss: 0.399413
# [888]	valid_0's binary_logloss: 0.399413
# [889]	valid_0's binary_logloss: 0.399414
# [890]	valid_0's binary_logloss: 0.399415
# [891]	valid_0's binary_logloss: 0.399421
# [892]	valid_0's binary_logloss: 0.399416
# [893]	valid_0's binary_logloss: 0.399417
# [894]	valid_0's binary_logloss: 0.399418
# [895]	valid_0's binary_logloss: 0.399411
# [896]	valid_0's binary_logloss: 0.399405
# [897]	valid_0's binary_logloss: 0.399403
# [898]	valid_0's binary_logloss: 0.399397
# [899]	valid_0's binary_logloss: 0.399395
# [900]	valid_0's binary_logloss: 0.399392
# [901]	valid_0's binary_logloss: 0.39939
# [902]	valid_0's binary_logloss: 0.399388
# [903]	valid_0's binary_logloss: 0.39939
# [904]	valid_0's binary_logloss: 0.399378
# [905]	valid_0's binary_logloss: 0.399373
# [906]	valid_0's binary_logloss: 0.399371
# [907]	valid_0's binary_logloss: 0.39936
# [908]	valid_0's binary_logloss: 0.399358
# [909]	valid_0's binary_logloss: 0.39936
# [910]	valid_0's binary_logloss: 0.399363
# [911]	valid_0's binary_logloss: 0.399363
# [912]	valid_0's binary_logloss: 0.399358
# [913]	valid_0's binary_logloss: 0.399346
# [914]	valid_0's binary_logloss: 0.399343
# [915]	valid_0's binary_logloss: 0.399346
# [916]	valid_0's binary_logloss: 0.399346
# [917]	valid_0's binary_logloss: 0.39935
# [918]	valid_0's binary_logloss: 0.399349
# [919]	valid_0's binary_logloss: 0.399352
# [920]	valid_0's binary_logloss: 0.39935
# [921]	valid_0's binary_logloss: 0.399353
# [922]	valid_0's binary_logloss: 0.39935
# [923]	valid_0's binary_logloss: 0.399354
# [924]	valid_0's binary_logloss: 0.399355
# [925]	valid_0's binary_logloss: 0.399356
# [926]	valid_0's binary_logloss: 0.399357
# [927]	valid_0's binary_logloss: 0.399359
# [928]	valid_0's binary_logloss: 0.399358
# [929]	valid_0's binary_logloss: 0.399359
# [930]	valid_0's binary_logloss: 0.399363
# [931]	valid_0's binary_logloss: 0.399365
# [932]	valid_0's binary_logloss: 0.399364
# [933]	valid_0's binary_logloss: 0.399365
# [934]	valid_0's binary_logloss: 0.399363
# [935]	valid_0's binary_logloss: 0.399359
# [936]	valid_0's binary_logloss: 0.39936
# [937]	valid_0's binary_logloss: 0.399359
# [938]	valid_0's binary_logloss: 0.399358
# [939]	valid_0's binary_logloss: 0.399355
# [940]	valid_0's binary_logloss: 0.399356
# [941]	valid_0's binary_logloss: 0.399354
# [942]	valid_0's binary_logloss: 0.399352
# [943]	valid_0's binary_logloss: 0.399348
# [944]	valid_0's binary_logloss: 0.399342
# [945]	valid_0's binary_logloss: 0.399342
# [946]	valid_0's binary_logloss: 0.399343
# [947]	valid_0's binary_logloss: 0.399341
# [948]	valid_0's binary_logloss: 0.399342
# [949]	valid_0's binary_logloss: 0.399344
# [950]	valid_0's binary_logloss: 0.399343
# [951]	valid_0's binary_logloss: 0.399346
# [952]	valid_0's binary_logloss: 0.399345
# [953]	valid_0's binary_logloss: 0.399351
# [954]	valid_0's binary_logloss: 0.399349
# [955]	valid_0's binary_logloss: 0.399347
# [956]	valid_0's binary_logloss: 0.399345
# [957]	valid_0's binary_logloss: 0.399348
# [958]	valid_0's binary_logloss: 0.399347
# [959]	valid_0's binary_logloss: 0.399343
# [960]	valid_0's binary_logloss: 0.39934
# [961]	valid_0's binary_logloss: 0.399338
# [962]	valid_0's binary_logloss: 0.399343
# [963]	valid_0's binary_logloss: 0.399345
# [964]	valid_0's binary_logloss: 0.399345
# [965]	valid_0's binary_logloss: 0.39934
# [966]	valid_0's binary_logloss: 0.39934
# [967]	valid_0's binary_logloss: 0.399341
# [968]	valid_0's binary_logloss: 0.399339
# [969]	valid_0's binary_logloss: 0.399338
# [970]	valid_0's binary_logloss: 0.39934
# [971]	valid_0's binary_logloss: 0.399342
# [972]	valid_0's binary_logloss: 0.399342
# [973]	valid_0's binary_logloss: 0.399346
# [974]	valid_0's binary_logloss: 0.399349
# [975]	valid_0's binary_logloss: 0.399348
# [976]	valid_0's binary_logloss: 0.399348
# [977]	valid_0's binary_logloss: 0.399348
# [978]	valid_0's binary_logloss: 0.399345
# [979]	valid_0's binary_logloss: 0.399341
# [980]	valid_0's binary_logloss: 0.399344
# [981]	valid_0's binary_logloss: 0.39934
# [982]	valid_0's binary_logloss: 0.399342
# [983]	valid_0's binary_logloss: 0.399341
# [984]	valid_0's binary_logloss: 0.399341
# [985]	valid_0's binary_logloss: 0.399343
# [986]	valid_0's binary_logloss: 0.39934
# [987]	valid_0's binary_logloss: 0.399342
# [988]	valid_0's binary_logloss: 0.399341
# [989]	valid_0's binary_logloss: 0.39934
# [990]	valid_0's binary_logloss: 0.399341
# [991]	valid_0's binary_logloss: 0.399341
# [992]	valid_0's binary_logloss: 0.399335
# [993]	valid_0's binary_logloss: 0.399338
# [994]	valid_0's binary_logloss: 0.399341
# [995]	valid_0's binary_logloss: 0.399346
# [996]	valid_0's binary_logloss: 0.399347
# [997]	valid_0's binary_logloss: 0.399348
# [998]	valid_0's binary_logloss: 0.399347
# [999]	valid_0's binary_logloss: 0.399351
# [1000]	valid_0's binary_logloss: 0.399348
# [1001]	valid_0's binary_logloss: 0.399345
# [1002]	valid_0's binary_logloss: 0.39934
# [1003]	valid_0's binary_logloss: 0.399335
# [1004]	valid_0's binary_logloss: 0.399335
# [1005]	valid_0's binary_logloss: 0.399333
# [1006]	valid_0's binary_logloss: 0.399335
# [1007]	valid_0's binary_logloss: 0.399331
# [1008]	valid_0's binary_logloss: 0.399331
# [1009]	valid_0's binary_logloss: 0.399327
# [1010]	valid_0's binary_logloss: 0.399318
# [1011]	valid_0's binary_logloss: 0.39931
# [1012]	valid_0's binary_logloss: 0.399303
# [1013]	valid_0's binary_logloss: 0.399303
# [1014]	valid_0's binary_logloss: 0.399302
# [1015]	valid_0's binary_logloss: 0.399298
# [1016]	valid_0's binary_logloss: 0.399299
# [1017]	valid_0's binary_logloss: 0.399302
# [1018]	valid_0's binary_logloss: 0.399304
# [1019]	valid_0's binary_logloss: 0.399297
# [1020]	valid_0's binary_logloss: 0.399296
# [1021]	valid_0's binary_logloss: 0.399296
# [1022]	valid_0's binary_logloss: 0.399295
# [1023]	valid_0's binary_logloss: 0.399292
# [1024]	valid_0's binary_logloss: 0.399288
# [1025]	valid_0's binary_logloss: 0.399278
# [1026]	valid_0's binary_logloss: 0.399277
# [1027]	valid_0's binary_logloss: 0.399272
# [1028]	valid_0's binary_logloss: 0.39927
# [1029]	valid_0's binary_logloss: 0.399269
# [1030]	valid_0's binary_logloss: 0.399268
# [1031]	valid_0's binary_logloss: 0.399267
# [1032]	valid_0's binary_logloss: 0.399262
# [1033]	valid_0's binary_logloss: 0.399262
# [1034]	valid_0's binary_logloss: 0.399261
# [1035]	valid_0's binary_logloss: 0.399263
# [1036]	valid_0's binary_logloss: 0.399253
# [1037]	valid_0's binary_logloss: 0.399254
# [1038]	valid_0's binary_logloss: 0.399253
# [1039]	valid_0's binary_logloss: 0.399249
# [1040]	valid_0's binary_logloss: 0.399249
# [1041]	valid_0's binary_logloss: 0.39925
# [1042]	valid_0's binary_logloss: 0.39925
# [1043]	valid_0's binary_logloss: 0.399251
# [1044]	valid_0's binary_logloss: 0.399252
# [1045]	valid_0's binary_logloss: 0.399251
# [1046]	valid_0's binary_logloss: 0.399251
# [1047]	valid_0's binary_logloss: 0.399252
# [1048]	valid_0's binary_logloss: 0.399251
# [1049]	valid_0's binary_logloss: 0.399252
# [1050]	valid_0's binary_logloss: 0.399252
# [1051]	valid_0's binary_logloss: 0.399255
# [1052]	valid_0's binary_logloss: 0.399253
# [1053]	valid_0's binary_logloss: 0.39925
# [1054]	valid_0's binary_logloss: 0.39925
# [1055]	valid_0's binary_logloss: 0.399251
# [1056]	valid_0's binary_logloss: 0.399249
# [1057]	valid_0's binary_logloss: 0.39925
# [1058]	valid_0's binary_logloss: 0.399249
# [1059]	valid_0's binary_logloss: 0.399246
# [1060]	valid_0's binary_logloss: 0.399245
# [1061]	valid_0's binary_logloss: 0.399251
# [1062]	valid_0's binary_logloss: 0.399249
# [1063]	valid_0's binary_logloss: 0.399249
# [1064]	valid_0's binary_logloss: 0.399251
# [1065]	valid_0's binary_logloss: 0.399249
# [1066]	valid_0's binary_logloss: 0.399245
# [1067]	valid_0's binary_logloss: 0.399244
# [1068]	valid_0's binary_logloss: 0.399242
# [1069]	valid_0's binary_logloss: 0.399243
# [1070]	valid_0's binary_logloss: 0.399244
# [1071]	valid_0's binary_logloss: 0.399246
# [1072]	valid_0's binary_logloss: 0.399245
# [1073]	valid_0's binary_logloss: 0.399248
# [1074]	valid_0's binary_logloss: 0.399249
# [1075]	valid_0's binary_logloss: 0.399253
# [1076]	valid_0's binary_logloss: 0.399253
# [1077]	valid_0's binary_logloss: 0.399252
# [1078]	valid_0's binary_logloss: 0.399252
# [1079]	valid_0's binary_logloss: 0.39925
# [1080]	valid_0's binary_logloss: 0.399249
# [1081]	valid_0's binary_logloss: 0.39925
# [1082]	valid_0's binary_logloss: 0.399245
# [1083]	valid_0's binary_logloss: 0.399246
# [1084]	valid_0's binary_logloss: 0.399241
# [1085]	valid_0's binary_logloss: 0.399242
# [1086]	valid_0's binary_logloss: 0.399241
# [1087]	valid_0's binary_logloss: 0.39924
# [1088]	valid_0's binary_logloss: 0.399244
# [1089]	valid_0's binary_logloss: 0.399247
# [1090]	valid_0's binary_logloss: 0.399246
# [1091]	valid_0's binary_logloss: 0.399247
# [1092]	valid_0's binary_logloss: 0.399245
# [1093]	valid_0's binary_logloss: 0.399245
# [1094]	valid_0's binary_logloss: 0.399243
# [1095]	valid_0's binary_logloss: 0.399242
# [1096]	valid_0's binary_logloss: 0.399241
# [1097]	valid_0's binary_logloss: 0.399237
# [1098]	valid_0's binary_logloss: 0.399236
# [1099]	valid_0's binary_logloss: 0.399235
# [1100]	valid_0's binary_logloss: 0.399237
# [1101]	valid_0's binary_logloss: 0.399236
# [1102]	valid_0's binary_logloss: 0.399236
# [1103]	valid_0's binary_logloss: 0.399234
# [1104]	valid_0's binary_logloss: 0.399238
# [1105]	valid_0's binary_logloss: 0.399233
# [1106]	valid_0's binary_logloss: 0.399236
# [1107]	valid_0's binary_logloss: 0.399229
# [1108]	valid_0's binary_logloss: 0.399232
# [1109]	valid_0's binary_logloss: 0.399235
# [1110]	valid_0's binary_logloss: 0.399227
# [1111]	valid_0's binary_logloss: 0.399224
# [1112]	valid_0's binary_logloss: 0.399226
# [1113]	valid_0's binary_logloss: 0.399226
# [1114]	valid_0's binary_logloss: 0.399224
# [1115]	valid_0's binary_logloss: 0.399226
# [1116]	valid_0's binary_logloss: 0.39922
# [1117]	valid_0's binary_logloss: 0.399218
# [1118]	valid_0's binary_logloss: 0.399214
# [1119]	valid_0's binary_logloss: 0.399216
# [1120]	valid_0's binary_logloss: 0.399211
# [1121]	valid_0's binary_logloss: 0.399212
# [1122]	valid_0's binary_logloss: 0.39921
# [1123]	valid_0's binary_logloss: 0.399199
# [1124]	valid_0's binary_logloss: 0.399197
# [1125]	valid_0's binary_logloss: 0.399197
# [1126]	valid_0's binary_logloss: 0.399199
# [1127]	valid_0's binary_logloss: 0.399195
# [1128]	valid_0's binary_logloss: 0.399195
# [1129]	valid_0's binary_logloss: 0.399193
# [1130]	valid_0's binary_logloss: 0.399187
# [1131]	valid_0's binary_logloss: 0.399183
# [1132]	valid_0's binary_logloss: 0.399187
# [1133]	valid_0's binary_logloss: 0.399188
# [1134]	valid_0's binary_logloss: 0.399191
# [1135]	valid_0's binary_logloss: 0.399185
# [1136]	valid_0's binary_logloss: 0.399185
# [1137]	valid_0's binary_logloss: 0.399182
# [1138]	valid_0's binary_logloss: 0.399184
# [1139]	valid_0's binary_logloss: 0.399187
# [1140]	valid_0's binary_logloss: 0.399186
# [1141]	valid_0's binary_logloss: 0.399184
# [1142]	valid_0's binary_logloss: 0.399186
# [1143]	valid_0's binary_logloss: 0.399185
# [1144]	valid_0's binary_logloss: 0.399183
# [1145]	valid_0's binary_logloss: 0.399183
# [1146]	valid_0's binary_logloss: 0.399183
# [1147]	valid_0's binary_logloss: 0.399182
# [1148]	valid_0's binary_logloss: 0.399188
# [1149]	valid_0's binary_logloss: 0.399187
# [1150]	valid_0's binary_logloss: 0.399186
# [1151]	valid_0's binary_logloss: 0.399186
# [1152]	valid_0's binary_logloss: 0.399188
# [1153]	valid_0's binary_logloss: 0.399188
# [1154]	valid_0's binary_logloss: 0.399186
# [1155]	valid_0's binary_logloss: 0.399184
# [1156]	valid_0's binary_logloss: 0.399183
# [1157]	valid_0's binary_logloss: 0.399184
# [1158]	valid_0's binary_logloss: 0.399185
# [1159]	valid_0's binary_logloss: 0.399184
# [1160]	valid_0's binary_logloss: 0.399184
# [1161]	valid_0's binary_logloss: 0.399182
# [1162]	valid_0's binary_logloss: 0.399184
# [1163]	valid_0's binary_logloss: 0.399185
# [1164]	valid_0's binary_logloss: 0.399191
# [1165]	valid_0's binary_logloss: 0.39919
# [1166]	valid_0's binary_logloss: 0.399187
# [1167]	valid_0's binary_logloss: 0.399189
# [1168]	valid_0's binary_logloss: 0.399187
# [1169]	valid_0's binary_logloss: 0.399189
# [1170]	valid_0's binary_logloss: 0.399188
# ...
# [1690]	valid_0's binary_logloss: 0.399001
# [1691]	valid_0's binary_logloss: 0.399003
# [1692]	valid_0's binary_logloss: 0.399003
# [1693]	valid_0's binary_logloss: 0.399007
# [1694]	valid_0's binary_logloss: 0.39901
# [1695]	valid_0's binary_logloss: 0.399013
# [1696]	valid_0's binary_logloss: 0.399019
# [1697]	valid_0's binary_logloss: 0.399018
# [1698]	valid_0's binary_logloss: 0.399015
# [1699]	valid_0's binary_logloss: 0.399018
# [1700]	valid_0's binary_logloss: 0.399023
# [1701]	valid_0's binary_logloss: 0.399021
# [1702]	valid_0's binary_logloss: 0.399025
# [1703]	valid_0's binary_logloss: 0.399024
# [1704]	valid_0's binary_logloss: 0.399026
# [1705]	valid_0's binary_logloss: 0.399025
# [1706]	valid_0's binary_logloss: 0.399026
# [1707]	valid_0's binary_logloss: 0.399026
# [1708]	valid_0's binary_logloss: 0.399021
# [1709]	valid_0's binary_logloss: 0.39902
# [1710]	valid_0's binary_logloss: 0.399018
# [1711]	valid_0's binary_logloss: 0.399021
# [1712]	valid_0's binary_logloss: 0.399018
# [1713]	valid_0's binary_logloss: 0.399019
# [1714]	valid_0's binary_logloss: 0.399019
# [1715]	valid_0's binary_logloss: 0.399014
# [1716]	valid_0's binary_logloss: 0.399014
# [1717]	valid_0's binary_logloss: 0.399015
# [1718]	valid_0's binary_logloss: 0.399012
# [1719]	valid_0's binary_logloss: 0.399012
# [1720]	valid_0's binary_logloss: 0.399013
# [1721]	valid_0's binary_logloss: 0.399012
# [1722]	valid_0's binary_logloss: 0.399013
# [1723]	valid_0's binary_logloss: 0.399004
# [1724]	valid_0's binary_logloss: 0.399005
# [1725]	valid_0's binary_logloss: 0.399002
# [1726]	valid_0's binary_logloss: 0.398999
# [1727]	valid_0's binary_logloss: 0.398999
# [1728]	valid_0's binary_logloss: 0.399003
# [1729]	valid_0's binary_logloss: 0.399002
# [1730]	valid_0's binary_logloss: 0.399
# [1731]	valid_0's binary_logloss: 0.398999
# [1732]	valid_0's binary_logloss: 0.398997
# [1733]	valid_0's binary_logloss: 0.398996
# [1734]	valid_0's binary_logloss: 0.399001
# [1735]	valid_0's binary_logloss: 0.399003
# [1736]	valid_0's binary_logloss: 0.399001
# [1737]	valid_0's binary_logloss: 0.399003
# [1738]	valid_0's binary_logloss: 0.399004
# [1739]	valid_0's binary_logloss: 0.399005
# [1740]	valid_0's binary_logloss: 0.399007
# [1741]	valid_0's binary_logloss: 0.399008
# [1742]	valid_0's binary_logloss: 0.399008
# [1743]	valid_0's binary_logloss: 0.399009
# [1744]	valid_0's binary_logloss: 0.399011
# [1745]	valid_0's binary_logloss: 0.399011
# [1746]	valid_0's binary_logloss: 0.399011
# [1747]	valid_0's binary_logloss: 0.399006
# [1748]	valid_0's binary_logloss: 0.399005
# [1749]	valid_0's binary_logloss: 0.399003
# [1750]	valid_0's binary_logloss: 0.398999
# [1751]	valid_0's binary_logloss: 0.399002
# [1752]	valid_0's binary_logloss: 0.399006
# [1753]	valid_0's binary_logloss: 0.399008
# [1754]	valid_0's binary_logloss: 0.39901
# [1755]	valid_0's binary_logloss: 0.39901
# [1756]	valid_0's binary_logloss: 0.399014
# [1757]	valid_0's binary_logloss: 0.399012
# [1758]	valid_0's binary_logloss: 0.399012
# [1759]	valid_0's binary_logloss: 0.399014
# [1760]	valid_0's binary_logloss: 0.399017
# [1761]	valid_0's binary_logloss: 0.399018
# [1762]	valid_0's binary_logloss: 0.399015
# [1763]	valid_0's binary_logloss: 0.399015
# [1764]	valid_0's binary_logloss: 0.399017
# [1765]	valid_0's binary_logloss: 0.399016
# [1766]	valid_0's binary_logloss: 0.399015
# [1767]	valid_0's binary_logloss: 0.399016
# [1768]	valid_0's binary_logloss: 0.399021
# [1769]	valid_0's binary_logloss: 0.399025
# [1770]	valid_0's binary_logloss: 0.399029
# [1771]	valid_0's binary_logloss: 0.399027
# [1772]	valid_0's binary_logloss: 0.399028
# [1773]	valid_0's binary_logloss: 0.39903
# [1774]	valid_0's binary_logloss: 0.399032
# [1775]	valid_0's binary_logloss: 0.39903
# [1776]	valid_0's binary_logloss: 0.39903
# [1777]	valid_0's binary_logloss: 0.399029
# [1778]	valid_0's binary_logloss: 0.399032
# [1779]	valid_0's binary_logloss: 0.399033
# [1780]	valid_0's binary_logloss: 0.399031
# [1781]	valid_0's binary_logloss: 0.399032
# [1782]	valid_0's binary_logloss: 0.399027
# [1783]	valid_0's binary_logloss: 0.399027
# [1784]	valid_0's binary_logloss: 0.399024
# [1785]	valid_0's binary_logloss: 0.399026
# [1786]	valid_0's binary_logloss: 0.399023
# [1787]	valid_0's binary_logloss: 0.39902
# [1788]	valid_0's binary_logloss: 0.399017
# [1789]	valid_0's binary_logloss: 0.39902
# [1790]	valid_0's binary_logloss: 0.399017
# [1791]	valid_0's binary_logloss: 0.399021
# [1792]	valid_0's binary_logloss: 0.399019
# [1793]	valid_0's binary_logloss: 0.399007
# [1794]	valid_0's binary_logloss: 0.399009
# [1795]	valid_0's binary_logloss: 0.399012
# [1796]	valid_0's binary_logloss: 0.399013
# [1797]	valid_0's binary_logloss: 0.399012
# [1798]	valid_0's binary_logloss: 0.39901
# [1799]	valid_0's binary_logloss: 0.39901
# [1800]	valid_0's binary_logloss: 0.399013
# [1801]	valid_0's binary_logloss: 0.399014
# [1802]	valid_0's binary_logloss: 0.399014
# [1803]	valid_0's binary_logloss: 0.399013
# [1804]	valid_0's binary_logloss: 0.399014
# [1805]	valid_0's binary_logloss: 0.399018
# [1806]	valid_0's binary_logloss: 0.39902
# [1807]	valid_0's binary_logloss: 0.399022
# [1808]	valid_0's binary_logloss: 0.399023
# [1809]	valid_0's binary_logloss: 0.399023
# [1810]	valid_0's binary_logloss: 0.399027
# [1811]	valid_0's binary_logloss: 0.399027
# [1812]	valid_0's binary_logloss: 0.399023
# [1813]	valid_0's binary_logloss: 0.399025
# [1814]	valid_0's binary_logloss: 0.39903
# [1815]	valid_0's binary_logloss: 0.39903
# [1816]	valid_0's binary_logloss: 0.399032
# [1817]	valid_0's binary_logloss: 0.399032
# [1818]	valid_0's binary_logloss: 0.399033
# [1819]	valid_0's binary_logloss: 0.399032
# [1820]	valid_0's binary_logloss: 0.399034
# [1821]	valid_0's binary_logloss: 0.399031
# [1822]	valid_0's binary_logloss: 0.39903
# [1823]	valid_0's binary_logloss: 0.39903
# [1824]	valid_0's binary_logloss: 0.399033
# [1825]	valid_0's binary_logloss: 0.399036
# [1826]	valid_0's binary_logloss: 0.399038
# [1827]	valid_0's binary_logloss: 0.399038
# [1828]	valid_0's binary_logloss: 0.39904
# [1829]	valid_0's binary_logloss: 0.399041
# [1830]	valid_0's binary_logloss: 0.39904
# [1831]	valid_0's binary_logloss: 0.399043
# [1832]	valid_0's binary_logloss: 0.399044
# [1833]	valid_0's binary_logloss: 0.399041
# [1834]	valid_0's binary_logloss: 0.399042
# [1835]	valid_0's binary_logloss: 0.39904
# [1836]	valid_0's binary_logloss: 0.399041
# [1837]	valid_0's binary_logloss: 0.399042
# [1838]	valid_0's binary_logloss: 0.399039
# [1839]	valid_0's binary_logloss: 0.399036
# [1840]	valid_0's binary_logloss: 0.399036
# [1841]	valid_0's binary_logloss: 0.399035
# [1842]	valid_0's binary_logloss: 0.399041
# [1843]	valid_0's binary_logloss: 0.39904
# [1844]	valid_0's binary_logloss: 0.399042
# [1845]	valid_0's binary_logloss: 0.399047
# [1846]	valid_0's binary_logloss: 0.399046
# [1847]	valid_0's binary_logloss: 0.39905
# [1848]	valid_0's binary_logloss: 0.39905
# [1849]	valid_0's binary_logloss: 0.399053
# [1850]	valid_0's binary_logloss: 0.399053
# [1851]	valid_0's binary_logloss: 0.399054
# [1852]	valid_0's binary_logloss: 0.399052
# [1853]	valid_0's binary_logloss: 0.399049
# [1854]	valid_0's binary_logloss: 0.399053
# [1855]	valid_0's binary_logloss: 0.399052
# [1856]	valid_0's binary_logloss: 0.39905
# [1857]	valid_0's binary_logloss: 0.399055
# [1858]	valid_0's binary_logloss: 0.399058
# [1859]	valid_0's binary_logloss: 0.399058
# [1860]	valid_0's binary_logloss: 0.399056
# [1861]	valid_0's binary_logloss: 0.399055
# [1862]	valid_0's binary_logloss: 0.399055
# [1863]	valid_0's binary_logloss: 0.39906
# [1864]	valid_0's binary_logloss: 0.399057
# [1865]	valid_0's binary_logloss: 0.399057
# [1866]	valid_0's binary_logloss: 0.399057
# [1867]	valid_0's binary_logloss: 0.399057
# [1868]	valid_0's binary_logloss: 0.399054
# [1869]	valid_0's binary_logloss: 0.399052
# [1870]	valid_0's binary_logloss: 0.399053
# [1871]	valid_0's binary_logloss: 0.399054
# [1872]	valid_0's binary_logloss: 0.399054
# [1873]	valid_0's binary_logloss: 0.399053
# [1874]	valid_0's binary_logloss: 0.39905
# [1875]	valid_0's binary_logloss: 0.399053
# [1876]	valid_0's binary_logloss: 0.399051
# [1877]	valid_0's binary_logloss: 0.399053
# [1878]	valid_0's binary_logloss: 0.399055
# [1879]	valid_0's binary_logloss: 0.39906
# [1880]	valid_0's binary_logloss: 0.399062
# [1881]	valid_0's binary_logloss: 0.399065
# [1882]	valid_0's binary_logloss: 0.399064
# [1883]	valid_0's binary_logloss: 0.399063
# [1884]	valid_0's binary_logloss: 0.399063
# [1885]	valid_0's binary_logloss: 0.399063
# [1886]	valid_0's binary_logloss: 0.39906
# [1887]	valid_0's binary_logloss: 0.399062
# [1888]	valid_0's binary_logloss: 0.399061
# [1889]	valid_0's binary_logloss: 0.399059
# [1890]	valid_0's binary_logloss: 0.399053
# [1891]	valid_0's binary_logloss: 0.399052
# [1892]	valid_0's binary_logloss: 0.399057
# [1893]	valid_0's binary_logloss: 0.399061
# [1894]	valid_0's binary_logloss: 0.399065
# [1895]	valid_0's binary_logloss: 0.399067
# [1896]	valid_0's binary_logloss: 0.39907
# [1897]	valid_0's binary_logloss: 0.399068
# [1898]	valid_0's binary_logloss: 0.399071
# [1899]	valid_0's binary_logloss: 0.39907
# [1900]	valid_0's binary_logloss: 0.399072
# [1901]	valid_0's binary_logloss: 0.399075
# [1902]	valid_0's binary_logloss: 0.399077
# [1903]	valid_0's binary_logloss: 0.399077
# [1904]	valid_0's binary_logloss: 0.39908
# [1905]	valid_0's binary_logloss: 0.399081
# [1906]	valid_0's binary_logloss: 0.399082
# [1907]	valid_0's binary_logloss: 0.399085
# [1908]	valid_0's binary_logloss: 0.399085
# [1909]	valid_0's binary_logloss: 0.399084
# [1910]	valid_0's binary_logloss: 0.399085
# [1911]	valid_0's binary_logloss: 0.399085
# [1912]	valid_0's binary_logloss: 0.399086
# [1913]	valid_0's binary_logloss: 0.399086
# [1914]	valid_0's binary_logloss: 0.399086
# [1915]	valid_0's binary_logloss: 0.399087
# [1916]	valid_0's binary_logloss: 0.399086
# [1917]	valid_0's binary_logloss: 0.399083
# [1918]	valid_0's binary_logloss: 0.399083
# [1919]	valid_0's binary_logloss: 0.399082
# [1920]	valid_0's binary_logloss: 0.399086
# [1921]	valid_0's binary_logloss: 0.399089
# [1922]	valid_0's binary_logloss: 0.399089
# [1923]	valid_0's binary_logloss: 0.399091
# [1924]	valid_0's binary_logloss: 0.399094
# [1925]	valid_0's binary_logloss: 0.399096
# [1926]	valid_0's binary_logloss: 0.399095
# [1927]	valid_0's binary_logloss: 0.399099
# [1928]	valid_0's binary_logloss: 0.399102
# [1929]	valid_0's binary_logloss: 0.399103
# [1930]	valid_0's binary_logloss: 0.399104
# [1931]	valid_0's binary_logloss: 0.399102
# [1932]	valid_0's binary_logloss: 0.3991
# [1933]	valid_0's binary_logloss: 0.399096
# [1934]	valid_0's binary_logloss: 0.399096
# [1935]	valid_0's binary_logloss: 0.3991
# [1936]	valid_0's binary_logloss: 0.399099
# [1937]	valid_0's binary_logloss: 0.399101
# [1938]	valid_0's binary_logloss: 0.399104
# [1939]	valid_0's binary_logloss: 0.399102
# [1940]	valid_0's binary_logloss: 0.399099
# [1941]	valid_0's binary_logloss: 0.399102
# [1942]	valid_0's binary_logloss: 0.399102
# [1943]	valid_0's binary_logloss: 0.399106
# [1944]	valid_0's binary_logloss: 0.399102
# [1945]	valid_0's binary_logloss: 0.399102
# [1946]	valid_0's binary_logloss: 0.399104
# [1947]	valid_0's binary_logloss: 0.399104
# [1948]	valid_0's binary_logloss: 0.399108
# [1949]	valid_0's binary_logloss: 0.399108
# [1950]	valid_0's binary_logloss: 0.39911
# [1951]	valid_0's binary_logloss: 0.399108
# [1952]	valid_0's binary_logloss: 0.399107
# [1953]	valid_0's binary_logloss: 0.399109
# [1954]	valid_0's binary_logloss: 0.399111
# [1955]	valid_0's binary_logloss: 0.399113
# [1956]	valid_0's binary_logloss: 0.399109
# [1957]	valid_0's binary_logloss: 0.399109
# [1958]	valid_0's binary_logloss: 0.39911
# [1959]	valid_0's binary_logloss: 0.399113
# [1960]	valid_0's binary_logloss: 0.399119
# [1961]	valid_0's binary_logloss: 0.399121
# [1962]	valid_0's binary_logloss: 0.399121
# [1963]	valid_0's binary_logloss: 0.399123
# [1964]	valid_0's binary_logloss: 0.399122
# [1965]	valid_0's binary_logloss: 0.399122
# [1966]	valid_0's binary_logloss: 0.399118
# [1967]	valid_0's binary_logloss: 0.399117
# [1968]	valid_0's binary_logloss: 0.399119
# [1969]	valid_0's binary_logloss: 0.399125
# [1970]	valid_0's binary_logloss: 0.399124
# [1971]	valid_0's binary_logloss: 0.399122
# [1972]	valid_0's binary_logloss: 0.399125
# [1973]	valid_0's binary_logloss: 0.399123
# [1974]	valid_0's binary_logloss: 0.399126
# [1975]	valid_0's binary_logloss: 0.399128
# [1976]	valid_0's binary_logloss: 0.399131
# [1977]	valid_0's binary_logloss: 0.399132
# [1978]	valid_0's binary_logloss: 0.399133
# [1979]	valid_0's binary_logloss: 0.399135
# [1980]	valid_0's binary_logloss: 0.399134
# [1981]	valid_0's binary_logloss: 0.399131
# [1982]	valid_0's binary_logloss: 0.399133
# [1983]	valid_0's binary_logloss: 0.399135
# [1984]	valid_0's binary_logloss: 0.399134
# [1985]	valid_0's binary_logloss: 0.399133
# [1986]	valid_0's binary_logloss: 0.399136
# [1987]	valid_0's binary_logloss: 0.399134
# [1988]	valid_0's binary_logloss: 0.399131
# [1989]	valid_0's binary_logloss: 0.39913
# [1990]	valid_0's binary_logloss: 0.399129
# [1991]	valid_0's binary_logloss: 0.399133
# [1992]	valid_0's binary_logloss: 0.399134
# [1993]	valid_0's binary_logloss: 0.399132
# [1994]	valid_0's binary_logloss: 0.399134
# [1995]	valid_0's binary_logloss: 0.399136
# [1996]	valid_0's binary_logloss: 0.399139
# [1997]	valid_0's binary_logloss: 0.399141
# [1998]	valid_0's binary_logloss: 0.399141
# [1999]	valid_0's binary_logloss: 0.399141
# [2000]	valid_0's binary_logloss: 0.399142
# [2001]	valid_0's binary_logloss: 0.399136
# [2002]	valid_0's binary_logloss: 0.399136
# [2003]	valid_0's binary_logloss: 0.399135
# [2004]	valid_0's binary_logloss: 0.399133
# [2005]	valid_0's binary_logloss: 0.399133
# [2006]	valid_0's binary_logloss: 0.399137
# [2007]	valid_0's binary_logloss: 0.399136
# [2008]	valid_0's binary_logloss: 0.399133
# [2009]	valid_0's binary_logloss: 0.399134
# [2010]	valid_0's binary_logloss: 0.399125
# [2011]	valid_0's binary_logloss: 0.399125
# [2012]	valid_0's binary_logloss: 0.399124
# [2013]	valid_0's binary_logloss: 0.39913
# [2014]	valid_0's binary_logloss: 0.399131
# [2015]	valid_0's binary_logloss: 0.399132
# [2016]	valid_0's binary_logloss: 0.399133
# [2017]	valid_0's binary_logloss: 0.39913
# [2018]	valid_0's binary_logloss: 0.399125
# [2019]	valid_0's binary_logloss: 0.399125
# [2020]	valid_0's binary_logloss: 0.399125
# [2021]	valid_0's binary_logloss: 0.399124
# [2022]	valid_0's binary_logloss: 0.399123
# [2023]	valid_0's binary_logloss: 0.399123
# [2024]	valid_0's binary_logloss: 0.399123
# [2025]	valid_0's binary_logloss: 0.399125
# [2026]	valid_0's binary_logloss: 0.399129
# [2027]	valid_0's binary_logloss: 0.39913
# [2028]	valid_0's binary_logloss: 0.399133
# [2029]	valid_0's binary_logloss: 0.399137
# [2030]	valid_0's binary_logloss: 0.399136
# [2031]	valid_0's binary_logloss: 0.399136
# [2032]	valid_0's binary_logloss: 0.399138
# [2033]	valid_0's binary_logloss: 0.399141
# [2034]	valid_0's binary_logloss: 0.399143
# [2035]	valid_0's binary_logloss: 0.399141
# [2036]	valid_0's binary_logloss: 0.399144
# [2037]	valid_0's binary_logloss: 0.39914
# [2038]	valid_0's binary_logloss: 0.399143
# [2039]	valid_0's binary_logloss: 0.399144
# [2040]	valid_0's binary_logloss: 0.399146
# [2041]	valid_0's binary_logloss: 0.399146
# [2042]	valid_0's binary_logloss: 0.399148
# [2043]	valid_0's binary_logloss: 0.399147
# [2044]	valid_0's binary_logloss: 0.399149
# [2045]	valid_0's binary_logloss: 0.399152
# [2046]	valid_0's binary_logloss: 0.39915
# [2047]	valid_0's binary_logloss: 0.399151
# [2048]	valid_0's binary_logloss: 0.39915
# [2049]	valid_0's binary_logloss: 0.399146
# [2050]	valid_0's binary_logloss: 0.399144
# [2051]	valid_0's binary_logloss: 0.399144
# [2052]	valid_0's binary_logloss: 0.399145
# [2053]	valid_0's binary_logloss: 0.399148
# [2054]	valid_0's binary_logloss: 0.399148
# [2055]	valid_0's binary_logloss: 0.399142
# [2056]	valid_0's binary_logloss: 0.399141
# [2057]	valid_0's binary_logloss: 0.399144
# [2058]	valid_0's binary_logloss: 0.399142
# [2059]	valid_0's binary_logloss: 0.399143
# [2060]	valid_0's binary_logloss: 0.399143
# [2061]	valid_0's binary_logloss: 0.399141
# [2062]	valid_0's binary_logloss: 0.399142
# [2063]	valid_0's binary_logloss: 0.399142
# [2064]	valid_0's binary_logloss: 0.399143
# [2065]	valid_0's binary_logloss: 0.399145
# [2066]	valid_0's binary_logloss: 0.399151
# [2067]	valid_0's binary_logloss: 0.39915
# [2068]	valid_0's binary_logloss: 0.399151
# [2069]	valid_0's binary_logloss: 0.399156
# Early stopping, best iteration is:
# [1569]	valid_0's binary_logloss: 0.398958

# %%
print(lgbm_model_v2.best_score)
print(lgbm_model_v2.best_iteration)
# Out:
# defaultdict(<class 'collections.OrderedDict'>, {'valid_0': OrderedDict([('binary_logloss', 0.3989578141157061)])})
# 1569

# %% [markdown]
# - The model had the best iteration of training at 1569th round with log_loss being lowest as "0.398957814115706"

# %% [markdown]
# ######Save the model

# %%
lgbm_model_v2.save_model('lgbm_model_logloss_0_39895')

# %%
lgbm_model_v2.feature_name()
# Out:
# ['dtype',
#  'dconn',
#  'pos',
#  'A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'G',
#  'H',
#  'I',
#  'hour_day',
#  'day',
#  'sid_int',
#  'sdomain_int',
#  'scat_int',
#  'aid_int',
#  'adomain_int',
#  'acat_int',
#  'did_int',
#  'dip_int',
#  'dmodel_int',
#  'week_day_int']

# %%
lgbm_model_v2.feature_importance()
# Out:
# array([ 264,  551,  422,  137, 3546,  235,  261, 1438,  696, 1760, 2446,
#        1503, 3986, 1727, 3184, 2710,  636, 2411, 1015,  758, 2718, 7038,
#        6273, 1355], dtype=int32)

# %% [markdown]
# ### Xgb boost with few fixed parameters

# %%
import xgboost as xgb
def to_train_xgb_certainparameters(X_train, X_test,y_train,y_test, features, target, random_state=0):
    eta = 0.1
    max_depth = 5
    subsample = 0.8
    colsample_bytree = 0.8
    print('XGBoost params. ETA: {}, MAX_DEPTH: {}, SUBSAMPLE: {}, COLSAMPLE_BY_TREE: {}'.format(eta, max_depth, subsample, colsample_bytree))
    params = {
        "objective": "binary:logistic",
        "booster" : "gbtree",
        "eval_metric": "logloss",
        "eta": eta,
        "max_depth": max_depth,
        "subsample": subsample,
        "colsample_bytree": colsample_bytree,
        "silent": 1,
        "seed": random_state
    }
    num_boost_round = 320
    early_stopping_rounds = 20
    

    
    dtrain = xgb.DMatrix(X_train[features], y_train)
    dvalid = xgb.DMatrix(X_test[features], y_test)
    watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
    xgboost_model = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=True)

# %%
to_train_xgb_certainparameters(X_train, X_test,y_train,y_test, features, 'like')
# Out:
# XGBoost params. ETA: 0.1, MAX_DEPTH: 5, SUBSAMPLE: 0.8, COLSAMPLE_BY_TREE: 0.8
# [14:58:12] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-logloss:0.64830	eval-logloss:0.64833
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 20 rounds.
# [1]	train-logloss:0.61172	eval-logloss:0.61212
# [2]	train-logloss:0.58139	eval-logloss:0.58197
# [3]	train-logloss:0.55663	eval-logloss:0.55696
# [4]	train-logloss:0.53566	eval-logloss:0.53599
# [5]	train-logloss:0.51801	eval-logloss:0.51845
# [6]	train-logloss:0.50310	eval-logloss:0.50350
# [7]	train-logloss:0.49056	eval-logloss:0.49107
# [8]	train-logloss:0.47974	eval-logloss:0.48029
# [9]	train-logloss:0.47075	eval-logloss:0.47127
# [10]	train-logloss:0.46302	eval-logloss:0.46355
# [11]	train-logloss:0.45626	eval-logloss:0.45688
# [12]	train-logloss:0.45082	eval-logloss:0.45147
# [13]	train-logloss:0.44599	eval-logloss:0.44673
# [14]	train-logloss:0.44190	eval-logloss:0.44264
# [15]	train-logloss:0.43843	eval-logloss:0.43912
# [16]	train-logloss:0.43531	eval-logloss:0.43611
# [17]	train-logloss:0.43270	eval-logloss:0.43344
# [18]	train-logloss:0.43055	eval-logloss:0.43141
# [19]	train-logloss:0.42856	eval-logloss:0.42946
# [20]	train-logloss:0.42696	eval-logloss:0.42785
# [21]	train-logloss:0.42548	eval-logloss:0.42639
# [22]	train-logloss:0.42412	eval-logloss:0.42515
# [23]	train-logloss:0.42318	eval-logloss:0.42419
# [24]	train-logloss:0.42206	eval-logloss:0.42307
# [25]	train-logloss:0.42121	eval-logloss:0.42234
# [26]	train-logloss:0.42049	eval-logloss:0.42156
# [27]	train-logloss:0.41975	eval-logloss:0.42094
# [28]	train-logloss:0.41941	eval-logloss:0.42051
# [29]	train-logloss:0.41884	eval-logloss:0.42001
# [30]	train-logloss:0.41823	eval-logloss:0.41944
# [31]	train-logloss:0.41768	eval-logloss:0.41889
# [32]	train-logloss:0.41709	eval-logloss:0.41839
# [33]	train-logloss:0.41680	eval-logloss:0.41801
# [34]	train-logloss:0.41642	eval-logloss:0.41770
# [35]	train-logloss:0.41615	eval-logloss:0.41745
# [36]	train-logloss:0.41588	eval-logloss:0.41715
# [37]	train-logloss:0.41552	eval-logloss:0.41680
# [38]	train-logloss:0.41503	eval-logloss:0.41634
# [39]	train-logloss:0.41485	eval-logloss:0.41622
# [40]	train-logloss:0.41468	eval-logloss:0.41600
# [41]	train-logloss:0.41429	eval-logloss:0.41562
# [42]	train-logloss:0.41410	eval-logloss:0.41547
# [43]	train-logloss:0.41386	eval-logloss:0.41529
# [44]	train-logloss:0.41374	eval-logloss:0.41515
# [45]	train-logloss:0.41341	eval-logloss:0.41489
# [46]	train-logloss:0.41323	eval-logloss:0.41473
# [47]	train-logloss:0.41312	eval-logloss:0.41461
# [48]	train-logloss:0.41297	eval-logloss:0.41443
# [49]	train-logloss:0.41282	eval-logloss:0.41432
# [50]	train-logloss:0.41273	eval-logloss:0.41421
# [51]	train-logloss:0.41242	eval-logloss:0.41400
# [52]	train-logloss:0.41226	eval-logloss:0.41381
# [53]	train-logloss:0.41208	eval-logloss:0.41365
# [54]	train-logloss:0.41201	eval-logloss:0.41358
# [55]	train-logloss:0.41178	eval-logloss:0.41333
# [56]	train-logloss:0.41150	eval-logloss:0.41304
# [57]	train-logloss:0.41135	eval-logloss:0.41292
# [58]	train-logloss:0.41107	eval-logloss:0.41269
# [59]	train-logloss:0.41085	eval-logloss:0.41250
# [60]	train-logloss:0.41079	eval-logloss:0.41246
# [61]	train-logloss:0.41064	eval-logloss:0.41234
# [62]	train-logloss:0.41055	eval-logloss:0.41226
# [63]	train-logloss:0.41033	eval-logloss:0.41208
# [64]	train-logloss:0.41015	eval-logloss:0.41193
# [65]	train-logloss:0.41008	eval-logloss:0.41188
# [66]	train-logloss:0.40994	eval-logloss:0.41174
# [67]	train-logloss:0.40970	eval-logloss:0.41147
# [68]	train-logloss:0.40944	eval-logloss:0.41124
# [69]	train-logloss:0.40938	eval-logloss:0.41119
# [70]	train-logloss:0.40929	eval-logloss:0.41111
# [71]	train-logloss:0.40920	eval-logloss:0.41104
# [72]	train-logloss:0.40904	eval-logloss:0.41090
# [73]	train-logloss:0.40900	eval-logloss:0.41085
# [74]	train-logloss:0.40895	eval-logloss:0.41081
# [75]	train-logloss:0.40882	eval-logloss:0.41069
# [76]	train-logloss:0.40864	eval-logloss:0.41055
# [77]	train-logloss:0.40858	eval-logloss:0.41049
# [78]	train-logloss:0.40849	eval-logloss:0.41042
# [79]	train-logloss:0.40840	eval-logloss:0.41034
# [80]	train-logloss:0.40822	eval-logloss:0.41021
# [81]	train-logloss:0.40816	eval-logloss:0.41016
# [82]	train-logloss:0.40806	eval-logloss:0.41010
# [83]	train-logloss:0.40795	eval-logloss:0.41004
# [84]	train-logloss:0.40784	eval-logloss:0.40993
# [85]	train-logloss:0.40772	eval-logloss:0.40983
# [86]	train-logloss:0.40759	eval-logloss:0.40972
# [87]	train-logloss:0.40745	eval-logloss:0.40960
# [88]	train-logloss:0.40741	eval-logloss:0.40958
# [89]	train-logloss:0.40728	eval-logloss:0.40945
# [90]	train-logloss:0.40720	eval-logloss:0.40938
# [91]	train-logloss:0.40715	eval-logloss:0.40934
# [92]	train-logloss:0.40706	eval-logloss:0.40925
# [93]	train-logloss:0.40694	eval-logloss:0.40915
# [94]	train-logloss:0.40686	eval-logloss:0.40907
# [95]	train-logloss:0.40678	eval-logloss:0.40900
# [96]	train-logloss:0.40666	eval-logloss:0.40890
# [97]	train-logloss:0.40655	eval-logloss:0.40879
# [98]	train-logloss:0.40647	eval-logloss:0.40874
# [99]	train-logloss:0.40642	eval-logloss:0.40869
# [100]	train-logloss:0.40636	eval-logloss:0.40865
# [101]	train-logloss:0.40627	eval-logloss:0.40858
# [102]	train-logloss:0.40624	eval-logloss:0.40857
# [103]	train-logloss:0.40616	eval-logloss:0.40850
# [104]	train-logloss:0.40613	eval-logloss:0.40848
# [105]	train-logloss:0.40607	eval-logloss:0.40844
# [106]	train-logloss:0.40597	eval-logloss:0.40835
# [107]	train-logloss:0.40587	eval-logloss:0.40825
# [108]	train-logloss:0.40579	eval-logloss:0.40818
# [109]	train-logloss:0.40571	eval-logloss:0.40812
# [110]	train-logloss:0.40563	eval-logloss:0.40804
# [111]	train-logloss:0.40555	eval-logloss:0.40798
# [112]	train-logloss:0.40548	eval-logloss:0.40794
# [113]	train-logloss:0.40538	eval-logloss:0.40786
# [114]	train-logloss:0.40532	eval-logloss:0.40782
# [115]	train-logloss:0.40525	eval-logloss:0.40774
# [116]	train-logloss:0.40517	eval-logloss:0.40767
# [117]	train-logloss:0.40507	eval-logloss:0.40759
# [118]	train-logloss:0.40502	eval-logloss:0.40756
# [119]	train-logloss:0.40495	eval-logloss:0.40749
# [120]	train-logloss:0.40486	eval-logloss:0.40740
# [121]	train-logloss:0.40477	eval-logloss:0.40732
# [122]	train-logloss:0.40471	eval-logloss:0.40726
# [123]	train-logloss:0.40465	eval-logloss:0.40721
# [124]	train-logloss:0.40456	eval-logloss:0.40714
# [125]	train-logloss:0.40450	eval-logloss:0.40710
# [126]	train-logloss:0.40445	eval-logloss:0.40706
# [127]	train-logloss:0.40438	eval-logloss:0.40701
# [128]	train-logloss:0.40435	eval-logloss:0.40698
# [129]	train-logloss:0.40429	eval-logloss:0.40694
# [130]	train-logloss:0.40421	eval-logloss:0.40686
# [131]	train-logloss:0.40416	eval-logloss:0.40684
# [132]	train-logloss:0.40414	eval-logloss:0.40682
# [133]	train-logloss:0.40410	eval-logloss:0.40680
# [134]	train-logloss:0.40403	eval-logloss:0.40675
# [135]	train-logloss:0.40399	eval-logloss:0.40674
# [136]	train-logloss:0.40393	eval-logloss:0.40669
# [137]	train-logloss:0.40386	eval-logloss:0.40662
# [138]	train-logloss:0.40381	eval-logloss:0.40659
# [139]	train-logloss:0.40379	eval-logloss:0.40657
# [140]	train-logloss:0.40374	eval-logloss:0.40654
# [141]	train-logloss:0.40372	eval-logloss:0.40653
# [142]	train-logloss:0.40371	eval-logloss:0.40652
# [143]	train-logloss:0.40364	eval-logloss:0.40648
# [144]	train-logloss:0.40361	eval-logloss:0.40646
# [145]	train-logloss:0.40358	eval-logloss:0.40644
# [146]	train-logloss:0.40351	eval-logloss:0.40640
# [147]	train-logloss:0.40344	eval-logloss:0.40634
# [148]	train-logloss:0.40337	eval-logloss:0.40627
# [149]	train-logloss:0.40331	eval-logloss:0.40623
# [150]	train-logloss:0.40326	eval-logloss:0.40619
# [151]	train-logloss:0.40319	eval-logloss:0.40613
# [152]	train-logloss:0.40316	eval-logloss:0.40612
# [153]	train-logloss:0.40313	eval-logloss:0.40610
# [154]	train-logloss:0.40310	eval-logloss:0.40609
# [155]	train-logloss:0.40308	eval-logloss:0.40608
# [156]	train-logloss:0.40305	eval-logloss:0.40606
# [157]	train-logloss:0.40303	eval-logloss:0.40603
# [158]	train-logloss:0.40292	eval-logloss:0.40594
# [159]	train-logloss:0.40288	eval-logloss:0.40591
# [160]	train-logloss:0.40285	eval-logloss:0.40589
# [161]	train-logloss:0.40282	eval-logloss:0.40588
# [162]	train-logloss:0.40280	eval-logloss:0.40587
# [163]	train-logloss:0.40274	eval-logloss:0.40582
# [164]	train-logloss:0.40265	eval-logloss:0.40573
# [165]	train-logloss:0.40262	eval-logloss:0.40571
# [166]	train-logloss:0.40256	eval-logloss:0.40566
# [167]	train-logloss:0.40247	eval-logloss:0.40558
# [168]	train-logloss:0.40239	eval-logloss:0.40552
# [169]	train-logloss:0.40235	eval-logloss:0.40548
# [170]	train-logloss:0.40231	eval-logloss:0.40545
# [171]	train-logloss:0.40225	eval-logloss:0.40541
# [172]	train-logloss:0.40218	eval-logloss:0.40535
# [173]	train-logloss:0.40214	eval-logloss:0.40533
# [174]	train-logloss:0.40211	eval-logloss:0.40531
# [175]	train-logloss:0.40206	eval-logloss:0.40527
# [176]	train-logloss:0.40201	eval-logloss:0.40523
# [177]	train-logloss:0.40191	eval-logloss:0.40513
# [178]	train-logloss:0.40184	eval-logloss:0.40508
# [179]	train-logloss:0.40182	eval-logloss:0.40507
# [180]	train-logloss:0.40176	eval-logloss:0.40502
# [181]	train-logloss:0.40173	eval-logloss:0.40500
# [182]	train-logloss:0.40169	eval-logloss:0.40497
# [183]	train-logloss:0.40166	eval-logloss:0.40495
# [184]	train-logloss:0.40164	eval-logloss:0.40494
# [185]	train-logloss:0.40160	eval-logloss:0.40491
# [186]	train-logloss:0.40154	eval-logloss:0.40486
# [187]	train-logloss:0.40150	eval-logloss:0.40484
# [188]	train-logloss:0.40145	eval-logloss:0.40480
# [189]	train-logloss:0.40141	eval-logloss:0.40476
# [190]	train-logloss:0.40136	eval-logloss:0.40472
# [191]	train-logloss:0.40134	eval-logloss:0.40471
# [192]	train-logloss:0.40127	eval-logloss:0.40465
# [193]	train-logloss:0.40120	eval-logloss:0.40458
# [194]	train-logloss:0.40115	eval-logloss:0.40453
# [195]	train-logloss:0.40111	eval-logloss:0.40451
# [196]	train-logloss:0.40106	eval-logloss:0.40448
# [197]	train-logloss:0.40103	eval-logloss:0.40446
# [198]	train-logloss:0.40099	eval-logloss:0.40442
# [199]	train-logloss:0.40093	eval-logloss:0.40440
# [200]	train-logloss:0.40089	eval-logloss:0.40437
# [201]	train-logloss:0.40086	eval-logloss:0.40436
# [202]	train-logloss:0.40085	eval-logloss:0.40436
# [203]	train-logloss:0.40083	eval-logloss:0.40435
# [204]	train-logloss:0.40077	eval-logloss:0.40429
# [205]	train-logloss:0.40071	eval-logloss:0.40424
# [206]	train-logloss:0.40069	eval-logloss:0.40424
# [207]	train-logloss:0.40065	eval-logloss:0.40421
# [208]	train-logloss:0.40060	eval-logloss:0.40417
# [209]	train-logloss:0.40058	eval-logloss:0.40416
# [210]	train-logloss:0.40056	eval-logloss:0.40415
# [211]	train-logloss:0.40052	eval-logloss:0.40412
# [212]	train-logloss:0.40048	eval-logloss:0.40410
# [213]	train-logloss:0.40043	eval-logloss:0.40407
# [214]	train-logloss:0.40038	eval-logloss:0.40404
# [215]	train-logloss:0.40033	eval-logloss:0.40401
# [216]	train-logloss:0.40032	eval-logloss:0.40400
# [217]	train-logloss:0.40027	eval-logloss:0.40397
# [218]	train-logloss:0.40023	eval-logloss:0.40396
# [219]	train-logloss:0.40019	eval-logloss:0.40394
# [220]	train-logloss:0.40014	eval-logloss:0.40389
# [221]	train-logloss:0.40008	eval-logloss:0.40385
# [222]	train-logloss:0.40003	eval-logloss:0.40381
# [223]	train-logloss:0.40001	eval-logloss:0.40380
# [224]	train-logloss:0.39999	eval-logloss:0.40379
# [225]	train-logloss:0.39994	eval-logloss:0.40376
# [226]	train-logloss:0.39992	eval-logloss:0.40375
# [227]	train-logloss:0.39989	eval-logloss:0.40373
# [228]	train-logloss:0.39988	eval-logloss:0.40372
# [229]	train-logloss:0.39986	eval-logloss:0.40372
# [230]	train-logloss:0.39984	eval-logloss:0.40372
# [231]	train-logloss:0.39983	eval-logloss:0.40371
# [232]	train-logloss:0.39976	eval-logloss:0.40366
# [233]	train-logloss:0.39969	eval-logloss:0.40360
# [234]	train-logloss:0.39968	eval-logloss:0.40360
# [235]	train-logloss:0.39965	eval-logloss:0.40357
# [236]	train-logloss:0.39961	eval-logloss:0.40355
# [237]	train-logloss:0.39960	eval-logloss:0.40355
# [238]	train-logloss:0.39955	eval-logloss:0.40353
# [239]	train-logloss:0.39951	eval-logloss:0.40349
# [240]	train-logloss:0.39949	eval-logloss:0.40349
# [241]	train-logloss:0.39944	eval-logloss:0.40343
# [242]	train-logloss:0.39939	eval-logloss:0.40340
# [243]	train-logloss:0.39936	eval-logloss:0.40340
# [244]	train-logloss:0.39933	eval-logloss:0.40337
# [245]	train-logloss:0.39931	eval-logloss:0.40336
# [246]	train-logloss:0.39930	eval-logloss:0.40335
# [247]	train-logloss:0.39926	eval-logloss:0.40333
# [248]	train-logloss:0.39921	eval-logloss:0.40329
# [249]	train-logloss:0.39919	eval-logloss:0.40328
# [250]	train-logloss:0.39918	eval-logloss:0.40328
# [251]	train-logloss:0.39917	eval-logloss:0.40326
# [252]	train-logloss:0.39914	eval-logloss:0.40326
# [253]	train-logloss:0.39911	eval-logloss:0.40324
# [254]	train-logloss:0.39908	eval-logloss:0.40322
# [255]	train-logloss:0.39906	eval-logloss:0.40321
# [256]	train-logloss:0.39904	eval-logloss:0.40321
# [257]	train-logloss:0.39900	eval-logloss:0.40319
# [258]	train-logloss:0.39897	eval-logloss:0.40317
# [259]	train-logloss:0.39893	eval-logloss:0.40315
# [260]	train-logloss:0.39891	eval-logloss:0.40314
# [261]	train-logloss:0.39889	eval-logloss:0.40312
# [262]	train-logloss:0.39887	eval-logloss:0.40312
# [263]	train-logloss:0.39883	eval-logloss:0.40309
# [264]	train-logloss:0.39880	eval-logloss:0.40308
# [265]	train-logloss:0.39878	eval-logloss:0.40308
# [266]	train-logloss:0.39877	eval-logloss:0.40307
# [267]	train-logloss:0.39875	eval-logloss:0.40307
# [268]	train-logloss:0.39871	eval-logloss:0.40303
# [269]	train-logloss:0.39866	eval-logloss:0.40299
# [270]	train-logloss:0.39863	eval-logloss:0.40298
# [271]	train-logloss:0.39861	eval-logloss:0.40297
# [272]	train-logloss:0.39857	eval-logloss:0.40295
# [273]	train-logloss:0.39854	eval-logloss:0.40294
# [274]	train-logloss:0.39846	eval-logloss:0.40287
# [275]	train-logloss:0.39845	eval-logloss:0.40287
# [276]	train-logloss:0.39841	eval-logloss:0.40284
# [277]	train-logloss:0.39834	eval-logloss:0.40280
# [278]	train-logloss:0.39831	eval-logloss:0.40278
# [279]	train-logloss:0.39830	eval-logloss:0.40278
# [280]	train-logloss:0.39828	eval-logloss:0.40277
# [281]	train-logloss:0.39825	eval-logloss:0.40276
# [282]	train-logloss:0.39824	eval-logloss:0.40276
# [283]	train-logloss:0.39822	eval-logloss:0.40275
# [284]	train-logloss:0.39820	eval-logloss:0.40274
# [285]	train-logloss:0.39818	eval-logloss:0.40273
# [286]	train-logloss:0.39814	eval-logloss:0.40270
# [287]	train-logloss:0.39810	eval-logloss:0.40268
# [288]	train-logloss:0.39808	eval-logloss:0.40267
# [289]	train-logloss:0.39806	eval-logloss:0.40267
# [290]	train-logloss:0.39804	eval-logloss:0.40265
# [291]	train-logloss:0.39799	eval-logloss:0.40263
# [292]	train-logloss:0.39794	eval-logloss:0.40259
# [293]	train-logloss:0.39792	eval-logloss:0.40259
# [294]	train-logloss:0.39791	eval-logloss:0.40259
# [295]	train-logloss:0.39788	eval-logloss:0.40257
# [296]	train-logloss:0.39786	eval-logloss:0.40257
# [297]	train-logloss:0.39784	eval-logloss:0.40256
# [298]	train-logloss:0.39781	eval-logloss:0.40253
# [299]	train-logloss:0.39778	eval-logloss:0.40251
# [300]	train-logloss:0.39775	eval-logloss:0.40249
# [301]	train-logloss:0.39771	eval-logloss:0.40248
# [302]	train-logloss:0.39768	eval-logloss:0.40247
# [303]	train-logloss:0.39767	eval-logloss:0.40246
# [304]	train-logloss:0.39764	eval-logloss:0.40245
# [305]	train-logloss:0.39764	eval-logloss:0.40245
# [306]	train-logloss:0.39760	eval-logloss:0.40242
# [307]	train-logloss:0.39758	eval-logloss:0.40242
# [308]	train-logloss:0.39756	eval-logloss:0.40242
# [309]	train-logloss:0.39754	eval-logloss:0.40240
# [310]	train-logloss:0.39750	eval-logloss:0.40237
# [311]	train-logloss:0.39747	eval-logloss:0.40236
# [312]	train-logloss:0.39745	eval-logloss:0.40236
# [313]	train-logloss:0.39744	eval-logloss:0.40234
# [314]	train-logloss:0.39741	eval-logloss:0.40233
# [315]	train-logloss:0.39739	eval-logloss:0.40233
# [316]	train-logloss:0.39736	eval-logloss:0.40231
# [317]	train-logloss:0.39733	eval-logloss:0.40230
# [318]	train-logloss:0.39730	eval-logloss:0.40228
# [319]	train-logloss:0.39727	eval-logloss:0.40226

# %% [markdown]
# - final output of Xgboost(few parameters) where training stopped: is train-logloss:0.39727 ,eval-logloss:0.40226

# %% [markdown]
# ### Keytakeaway

# %% [markdown]
# - From all the above models, we can clearly see that LGBM(Tuned with Few Parameters) Classifier is better compared to rest all models with Lowest Log_loss of 0.3989 been recorded .
#
#
# - On other hand Xgboost defaultmodel(0.4013) performed better than Xgb(Tuned with few Parameters) with logloss(0.40226).The more the time spend of hyperparamter tuning etc and feature engineering could improve these scores further.
#
#
# - I have also tried Using H2oAutoML for ensemble modelling in other notebook (Automl_H2o_Modelling) as it does stacking and merging of multiple models together for better accuracy . Here the best model(GBM_5_AutoML_20201017_111216) was with lowest log_loss of '0.399712'.

# %% [markdown]
# ### Areas of Future Improvements :

# %% [markdown]
#
# - 1.Hyperparamter Tuning using Gridsearch/RandomsearchCV/Hyperopt and other  tuning techniques to be implemented to further finetune models.Right now because of the size of dataset and also time constraints,I couldnot spend more time on this aspect of modelling.
#
#
# - 2.Incremental learning and other Gradient techniques could be used to learn the whole dataset in chunks instead of relying on random sample.We can also use PySpark MLLib to handle such bigdatasets in cluster environment.
#
#
# - 3.FFM(Field Aware Factorization Machines) algorithms have proven better in online ad CTR prediction.This could be implemented using LibFFM library or xlearn.Factorization Machines are usually trained by using one of the three main solvers – Stochastic Gradient Descent (SGD), Alternative Least Squares (ALS) or Markov Chain Monte Carlo (MCMC).
#
#
# - 4.Encoding technqiues like Mean encoders or Onehot encoders could be tried to see the effect of curse of dimensionality during training process.
#
#
# - 5.As part of feature engineering , did(device id),device ip(dip),device model(dmodel) could be merged to get better representation of users.As we have seen 85% of data is originating from one single device.We can identify the user with device id if it is not null and device ip(dip) + device model(dmodel) for others
#
#
# - 6.Similarly Site ID (sid),Site domain (sdomain) could be merged to better represent publishers site.
#
# - 7.Recursive Feature elimination and other feature selection techniques can be tried for reducing the feature space etc.
